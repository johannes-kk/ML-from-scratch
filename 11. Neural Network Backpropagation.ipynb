# %% [markdown]
# # 11. Neural Network Backpropagation

# %%
from random import seed, randrange, random
from math import exp

from functions import *

# %% [markdown]
# ### Define functions
# * Simple neural network with a single hidden layer using backpropagation

# %%
# Initialize a network of one hidden layer
# Input: number of inputs (features), number of neurons in hidden layer, number of outputs
# Output: network, a list of layers, each a list of dictionaries (one per neuron)
def initialize_network(n_inputs, n_hidden, n_outputs):
    # Create an array (list) of layers, each an array of node dictionaries
    network = list()
    # Hidden layer = list of dictionaries, so repeated n_hidden times
    # Each dictionary has key "weights" with value = list of input (neuron) weights (+1 for bias)
    hidden_layer = [{"weights": [random() for i in range(n_inputs + 1)]} for i in range(n_hidden)]
    network.append(hidden_layer)
    # Since feedforward, it's now n_hidden weights per neuron in (output) layer
    # n_outputs number of nodes, since want as many as there are classes
    output_layer = [{"weights": [random() for i in range(n_hidden + 1)]} for i in range(n_outputs)]
    network.append(output_layer)
    return network

# Calculate neuron activation for an input
# Input: weights (of neuron), inputs (whether row of data or output from previous layer of neurons)
# Output: activation (the activation value itself, regardless of activation threshold)
def activate_neuron(weights, inputs):
    # Initialize activation equal to bias (assumed to be in last position)
    activation = weights[-1]
    # Multiply each input with corresponding weight, except the bias (assumed last) since constant
    for i in range(len(weights)-1):
        activation += weights[i] * inputs[i]
    return activation

# Sigmoid transfer a neuron activation
# Input: neuron activation value
# Output: sigmoid transferred value between 0 and 1
def transfer_sigmoid(activation):
    return 1.0 / (1.0 + exp(-activation))

# Feed a row of data forward through the network
# Input: network (list of layers, each a list of dictionaries - one per neuron), row of data
# Output: list of Sigmoid transferred activations of output layer
def forward_propagate(network, row):
    # Store raw row of data in a var, which is updated to layer outputs as the data is fed forward
    inputs = row
    # Iterate over lists, one per layer, each in turn a list of dictionaries (neurons)
    for layer in network:
        # Array to collect outputs for a layer, later used as inputs for the following layer
        new_inputs = []
        # Iterate over neurons in layer, each a dictionary with key 'weights'; value list of weights
        for neuron in layer:
            # Calculate the neuron activation, given its weights and the provided input
            activation = activate_neuron(neuron["weights"], inputs)
            # Store the neuron's output, having transferred the activation via the Sigmoid function
            neuron["output"] = transfer_sigmoid(activation)
            new_inputs.append(neuron["output"])
        # Update "inputs" to the output of the last layer (rather than the raw input data)
        inputs = new_inputs
        # Data is fed forward; new "inputs" now the output of previous layer rather than raw data
    # After data is fed forward through all layers, return the final layer transferred activations
    return inputs

# Calculate the derivative of an observed neuron output, assuming Sigmoid transfer of activation
# Input: Sigmoid transferred neuron activation output
# Output: Derivative of Sigmoid transferred neuron activation output
def transfer_sigmoid_derivative(output):
    return output * (1.0 - output)

# Back-propagate error and store in neurons
# Input: network object (list of layers; lists of dictionaries (nodes)), expected outputs
# Output: None. Adds or updates "delta" (error signal) for each neuron in network (passed by ref.)
def backward_propagate_error(network, expected):
    # Iterate over network in reverse order, starting at output layer and working backwards
        # A node's weights in output layer correspond to neurons in previous hidden layer
    # "delta" = error signal for a neuron; name chosen for error's change on neuron (weight delta)
    # Error signal for neurons in hidden layer is accumulated from neurons in output layer, where
    # hidden neuron number j is also index of neuron's weight in output layer neuron['weights'][j]
    # Each i in the network is index of a layer, itself a list of dictionaries (one per neuron)
    for i in reversed(range(len(network))):
        # Extract layer, i.e. list of dictionaries
        layer = network[i]
        errors = list()
        # If not in the output layer (last i), we're in a hidden layer
        if i != len(network)-1:
            # Iterate over nodes (dictionaries) in (hidden) layer i (list)
            for j in range(len(layer)):
                # Initialize neuron error to 0
                error = 0.0
                # Iterate over all neurons in upper layer (i.e. output layer for last hidden layer)
                # Error signal of hidden layer neuron is weighted errors of all neurons in next layer
                for neuron in network[i + 1]:
                    # For neuron j in i, multiply all upper neurons' error/delta with its weight to j
                        # Neuron j's error is its total blame for upper layer errors
                    # E.g. j=1 is 2nd neuron in hidden layer. For each node in output layer,
                    # multiply its 2nd weight (connecting it to j=1 in hidden) with its error.
                    error += (neuron["weights"][j] * neuron["delta"])
                # Add neuron j's error (weight of all connected neuron errors in next layer) to list
                errors.append(error)
        # Else we are in the output layer, so error = simple difference of expected vs actual output
        # We arrive here in the first iteration, i.e. we start by calculating deltas of output layer
        else:
            # Iterate over neurons in output layer
            for j in range(len(layer)):
                # Get dictionary object that makes up the neuron
                neuron = layer[j]
                # Calculate error as difference between expected and actual output, and add to list
                errors.append(expected[j] - neuron["output"])
        # Once all layer neuron errors are calculated, update all neuron dictionaries with error
        # "delta" is final error measure, i.e. (expected - actual) * transfer_derivative
        for j in range(len(layer)):
            neuron = layer[j]
            # Calculate "delta" and assign to neuron's dictionary's key's value
            neuron["delta"] = errors[j] * transfer_sigmoid_derivative(neuron["output"])

# Update the neuron weights for a network where error signals ("delta") have been back-propagated
# Input: network with back-propagated error signals, row of input data, learning rate
# Output: None. Updated neuron weights across network, since network is passed by reference.
def update_weights(network, row, l_rate):
    # Iterate over layers in network, from input layer, through hidden, to output layer
    for i in range(len(network)):
        # Get inputs as all raw row data except last column (assumed to be the output, e.g. class)
        inputs = row[:-1]
        # If not in input layer, get input as output of previous layer, rather than row of raw data
        if i != 0:
            # Update "inputs" to list of all neuron outputs from lower/previous layer
            inputs = [neuron["output"] for neuron in network[i - 1]]
        # Iterate over all neurons in layer i
        for neuron in network[i]:
            # Iterate over inputs, whether M columns or N outputs from previous layer's N neurons
            for j in range(len(inputs)):
                # Update current neuron's weight_j by adding learning rate * error * input_j
                neuron["weights"][j] += l_rate * neuron["delta"] * inputs[j]
            # Update bias "weight"; no corresponding input to multiply with
            neuron["weights"][-1] += l_rate * neuron["delta"]

# Train a network for a fixed number of epochs
# Input: initialized network, training dataset, learning rate, number of epochs, number of outputs
# Output: None. Calls update_weights #epochs times, updating the given network passed by reference.
def train_network(network, train, l_rate, n_epoch, n_outputs):
    # Repeat for given number of epochs
    for epoch in range(n_epoch):
        # Initialize epoch sum squared error
        sum_error = 0
        # Iterate over training data
        for row in train:
            # Feed in current training row to get Sigmoid transferred activations of output neurons
            outputs = forward_propagate(network, row)
            # ONE-HOT ENCODE EXPECTED OUTPUTS
                # Ideal output would be 100% probability of correct class, 0% of all others
            # Initialize list of expected outputs to 0's
            expected = [0 for i in range(n_outputs)]
            # row[-1] = true class; output neurons are ordered so update same index of expected to 1
            expected[row[-1]] = 1
            # Increment epoch sum of squared errors of output vs one-hot encoded expectation
                # Sort of Cross Entropy (but not entirely, right?)
            sum_error += sum([(expected[i]-outputs[i])**2 for i in range(len(expected))])
            # Backward-propagate expected one-hot encoded output to update neuron error signals
            backward_propagate_error(network, expected)
            # Update neuron weights based on current row (cause of error) and updated error signals
            update_weights(network, row, l_rate)
        print('>epoch=%d, lrate=%.3f, error=%.3f' % (epoch, l_rate, sum_error))

# Make a prediction with a trained network
# Input: trained network, row of input data
# Output: index of network output with largest probability, i.e. the predicted class number
def predict_network(network, row):
    outputs = forward_propagate(network, row)
    return outputs.index(max(outputs))

# Manages application of the back-propagation algorithm, and initialization and training of network
    # Note: can only create networks of one hidden layer
# Input: train and test datasets, learning rate, number of epochs, number of neurons in hidden layer
# Output: predicted outputs for test dataset
def back_propagation(train, test, l_rate, n_epoch, n_hidden):
    # Number of inputs, assuming last row column is the output
    n_inputs = len(train[0]) - 1
    # Number of unique outputs in training set, assumed to represent number of classes/outputs
    n_outputs = len(set([row[-1] for row in train]))
    # Initialize a network with one hidden layer
    network = initialize_network(n_inputs, n_hidden, n_outputs)
    # Train neural network, repeatedly feed-forwarding data points and back-propagating errors
    train_network(network, train, l_rate, n_epoch, n_outputs)
    # Create list to hold predictions
    predictions = list()
    # Iterate over test data
    for row in test:
        # For the network, feed a row of input data forward through network and capture prediction
        prediction = predict_network(network, row)
        predictions.append(prediction)
    return predictions

# %% [markdown]
# ### Testing neural net on contrived dataset

# %%
# Test initializing a network
seed(1)
# 2 inputs (neurons), 1 neuron in hidden layer, 2 outputs (neurons)
network = initialize_network(2, 1, 2)
# Creates one hidden layer w/ one neuron w/ three weights, output of two neurons w/ two weights
print("Initialized network architecture:")
for layer in network:
    print(layer)

# Test forward propagation
network = [[{'weights': [0.13436424411240122, 0.8474337369372327, 0.763774618976614]}],
[{'weights': [0.2550690257394217, 0.49543508709194095]}, {'weights':
[0.4494910647887381, 0.651592972722763]}]]
row = [1, 0, None]
output = forward_propagate(network, row)
print("\nOutput from forward propagation of input:")
print(output)
# Propagates input pattern [1,0] and produces an output value that is printed
# Because the output layer has two neurons, we get a list of two numbers as output
# The actual output values are just nonsense for now, and will need to be converted (e.g. SoftMax)

# Test backpropagation of error
network = [
    [
        {'output': 0.7105668883115941,
         'weights': [0.13436424411240122, 0.8474337369372327, 0.763774618976614]}
    ],
    [
        {'output': 0.6213859615555266,
         'weights': [0.2550690257394217, 0.49543508709194095]},
        {'output': 0.6573693455986976,
         'weights': [0.4494910647887381, 0.651592972722763]}
     ]
]
expected = [0, 1]
backward_propagate_error(network, expected)
print("\nNetwork after backpropagation of error:")
for layer in network:
    print(layer)

# Test training backprop algorithm
print("\nTraining network, with final structure:")
seed(1)
dataset = [[2.7810836,2.550537003,0],
[1.465489372,2.362125076,0],
[3.396561688,4.400293529,0],
[1.38807019,1.850220317,0],
[3.06407232,3.005305973,0],
[7.627531214,2.759262235,1],
[5.332441248,2.088626775,1],
[6.922596716,1.77106367,1],
[8.675418651,-0.242068655,1],
[7.673756466,3.508563011,1]]
# Get number of inputs, assuming last column is output
n_inputs = len(dataset[0]) - 1
# Count number of distinct classes
n_outputs = len(set([row[-1] for row in dataset]))
# Network with 2 input neurons, 2 neurons in hidden layer, 2 outputs
network = initialize_network(n_inputs, 2, n_outputs)
learning_rate = 0.5
epochs = 20
train_network(network, dataset, learning_rate, epochs, n_outputs)
for layer in network:
    print(layer)

# Test making predictions with the network
dataset = [[2.7810836,2.550537003,0],
[1.465489372,2.362125076,0],
[3.396561688,4.400293529,0],
[1.38807019,1.850220317,0],
[3.06407232,3.005305973,0],
[7.627531214,2.759262235,1],
[5.332441248,2.088626775,1],
[6.922596716,1.77106367,1],
[8.675418651,-0.242068655,1],
[7.673756466,3.508563011,1]]
network = [[{'weights': [-1.482313569067226, 1.8308790073202204, 1.078381922048799]},
{'weights': [0.23244990332399884, 0.3621998343835864, 0.40289821191094327]}],
[{'weights': [2.5001872433501404, 0.7887233511355132, -1.1026649757805829]}, {'weights':
[-2.429350576245497, 0.8357651039198697, 1.0699217181280656]}]]
print("\nMaking predictions with the trained network:")
for row in dataset:
    prediction = predict_network(network, row)
    print('Expected=%d, Got=%d' % (row[-1], prediction))
# The 100% accuracy is not unexpected considering we're predicting the same rows used to train
# Out:
# Initialized network architecture:
# [{'weights': [0.13436424411240122, 0.8474337369372327, 0.763774618976614]}]
# [{'weights': [0.2550690257394217, 0.49543508709194095]}, {'weights': [0.4494910647887381, 0.651592972722763]}]
#
# Output from forward propagation of input:
# [0.6629970129852887, 0.7253160725279748]
#
# Network after backpropagation of error:
# [{'output': 0.7105668883115941, 'weights': [0.13436424411240122, 0.8474337369372327, 0.763774618976614], 'delta': -0.0005348048046610517}]
# [{'output': 0.6213859615555266, 'weights': [0.2550690257394217, 0.49543508709194095], 'delta': -0.14619064683582808}, {'output': 0.6573693455986976, 'weights': [0.4494910647887381, 0.651592972722763], 'delta': 0.0771723774346327}]
#
# Training network, with final structure:
# >epoch=0, lrate=0.500, error=6.350
# >epoch=1, lrate=0.500, error=5.531
# >epoch=2, lrate=0.500, error=5.221
# >epoch=3, lrate=0.500, error=4.951
# >epoch=4, lrate=0.500, error=4.519
# >epoch=5, lrate=0.500, error=4.173
# >epoch=6, lrate=0.500, error=3.835
# >epoch=7, lrate=0.500, error=3.506
# >epoch=8, lrate=0.500, error=3.192
# >epoch=9, lrate=0.500, error=2.898
# >epoch=10, lrate=0.500, error=2.626
# >epoch=11, lrate=0.500, error=2.377
# >epoch=12, lrate=0.500, error=2.153
# >epoch=13, lrate=0.500, error=1.953
# >epoch=14, lrate=0.500, error=1.774
# >epoch=15, lrate=0.500, error=1.614
# >epoch=16, lrate=0.500, error=1.472
# >epoch=17, lrate=0.500, error=1.346
# >epoch=18, lrate=0.500, error=1.233
# >epoch=19, lrate=0.500, error=1.132
# [{'weights': [-1.4688375095432327, 1.850887325439514, 1.0858178629550297], 'output': 0.029980305604426185, 'delta': -0.0059546604162323625}, {'weights': [0.37711098142462157, -0.0625909894552989, 0.2765123702642716], 'output': 0.9456229000211323, 'delta': 0.0026279652850863837}]
# [{'weights': [2.515394649397849, -0.3391927502445985, -0.9671565426390275], 'output': 0.23648794202357587, 'delta': -0.04270059278364587}, {'weights': [-2.5584149848484263, 1.0036422106209202, 0.42383086467582715], 'output': 0.7790535202438367, 'delta': 0.03803132596437354}]
#
# Making predictions with the trained network:
# Expected=0, Got=0
# Expected=0, Got=0
# Expected=0, Got=0
# Expected=0, Got=0
# Expected=0, Got=0
# Expected=1, Got=1
# Expected=1, Got=1
# Expected=1, Got=1
# Expected=1, Got=1
# Expected=1, Got=1

# %% [markdown]
# ### Testing neural net on Wheat Seeds dataset

# %%
# With k-fold cross-validation with 5 folds, 201/5 = 40.2 = 40 records per fold
seed(1)
print("\nWheat Seeds Case Study")
dataset = load_csv("data/seeds_dataset.csv")
# Convert features from string numbers to floats
for i in range(len(dataset[0])-1):
    str_column_to_float(dataset, i)
# Convert string class to int
str_column_to_int(dataset, len(dataset[0])-1)
# Input values vary in scale and need to be normalized to the range of 0 and 1.
# Normalize inputs
minmax = dataset_minmax(dataset)
    # Note: had to fix normalize_dataset so it didn't normalize the class label output
normalize_dataset(dataset, minmax)
# Evaluate algorithm
n_folds = 5
l_rate = 0.3
n_epoch = 500
n_hidden = 5
scores = evaluate_algorithm(dataset, back_propagation, n_folds, accuracy_metric, l_rate, n_epoch, n_hidden)
print('Scores ANN: %s' % scores)
print('Mean Accuracy ANN: %.3f%%' % (sum(scores)/float(len(scores))))
# Out:
# Wheat Seeds Case Study
# Loaded data file data/seeds_dataset.csv with 210 rows and 8 columns.
# >epoch=0, lrate=0.300, error=130.992
# >epoch=1, lrate=0.300, error=106.670
# >epoch=2, lrate=0.300, error=96.449
# >epoch=3, lrate=0.300, error=84.989
# >epoch=4, lrate=0.300, error=75.873
# >epoch=5, lrate=0.300, error=69.593
# >epoch=6, lrate=0.300, error=65.094
# >epoch=7, lrate=0.300, error=61.433
# >epoch=8, lrate=0.300, error=58.012
# >epoch=9, lrate=0.300, error=54.499
# >epoch=10, lrate=0.300, error=50.801
# >epoch=11, lrate=0.300, error=47.061
# >epoch=12, lrate=0.300, error=43.548
# >epoch=13, lrate=0.300, error=40.466
# >epoch=14, lrate=0.300, error=37.879
# >epoch=15, lrate=0.300, error=35.750
# >epoch=16, lrate=0.300, error=34.007
# >epoch=17, lrate=0.300, error=32.572
# >epoch=18, lrate=0.300, error=31.378
# >epoch=19, lrate=0.300, error=30.371
# >epoch=20, lrate=0.300, error=29.509
# >epoch=21, lrate=0.300, error=28.761
# >epoch=22, lrate=0.300, error=28.101
# >epoch=23, lrate=0.300, error=27.512
# >epoch=24, lrate=0.300, error=26.979
# >epoch=25, lrate=0.300, error=26.490
# >epoch=26, lrate=0.300, error=26.038
# >epoch=27, lrate=0.300, error=25.614
# >epoch=28, lrate=0.300, error=25.215
# >epoch=29, lrate=0.300, error=24.836
# >epoch=30, lrate=0.300, error=24.472
# >epoch=31, lrate=0.300, error=24.122
# >epoch=32, lrate=0.300, error=23.784
# >epoch=33, lrate=0.300, error=23.454
# >epoch=34, lrate=0.300, error=23.133
# >epoch=35, lrate=0.300, error=22.819
# >epoch=36, lrate=0.300, error=22.510
# >epoch=37, lrate=0.300, error=22.208
# >epoch=38, lrate=0.300, error=21.910
# >epoch=39, lrate=0.300, error=21.617
# >epoch=40, lrate=0.300, error=21.328
# >epoch=41, lrate=0.300, error=21.044
# >epoch=42, lrate=0.300, error=20.765
# >epoch=43, lrate=0.300, error=20.490
# >epoch=44, lrate=0.300, error=20.220
# >epoch=45, lrate=0.300, error=19.955
# >epoch=46, lrate=0.300, error=19.695
# >epoch=47, lrate=0.300, error=19.441
# >epoch=48, lrate=0.300, error=19.192
# >epoch=49, lrate=0.300, error=18.949
# >epoch=50, lrate=0.300, error=18.712
# >epoch=51, lrate=0.300, error=18.481
# >epoch=52, lrate=0.300, error=18.256
# >epoch=53, lrate=0.300, error=18.037
# >epoch=54, lrate=0.300, error=17.824
# >epoch=55, lrate=0.300, error=17.617
# >epoch=56, lrate=0.300, error=17.415
# >epoch=57, lrate=0.300, error=17.220
# >epoch=58, lrate=0.300, error=17.031
# >epoch=59, lrate=0.300, error=16.847
# >epoch=60, lrate=0.300, error=16.669
# >epoch=61, lrate=0.300, error=16.496
# >epoch=62, lrate=0.300, error=16.329
# >epoch=63, lrate=0.300, error=16.167
# >epoch=64, lrate=0.300, error=16.010
# >epoch=65, lrate=0.300, error=15.857
# >epoch=66, lrate=0.300, error=15.710
# >epoch=67, lrate=0.300, error=15.567
# >epoch=68, lrate=0.300, error=15.428
# >epoch=69, lrate=0.300, error=15.294
# >epoch=70, lrate=0.300, error=15.164
# >epoch=71, lrate=0.300, error=15.039
# >epoch=72, lrate=0.300, error=14.917
# >epoch=73, lrate=0.300, error=14.799
# >epoch=74, lrate=0.300, error=14.684
# >epoch=75, lrate=0.300, error=14.573
# >epoch=76, lrate=0.300, error=14.465
# >epoch=77, lrate=0.300, error=14.361
# >epoch=78, lrate=0.300, error=14.260
# >epoch=79, lrate=0.300, error=14.161
# >epoch=80, lrate=0.300, error=14.066
# >epoch=81, lrate=0.300, error=13.973
# >epoch=82, lrate=0.300, error=13.883
# >epoch=83, lrate=0.300, error=13.796
# >epoch=84, lrate=0.300, error=13.711
# >epoch=85, lrate=0.300, error=13.628
# >epoch=86, lrate=0.300, error=13.547
# >epoch=87, lrate=0.300, error=13.469
# >epoch=88, lrate=0.300, error=13.393
# >epoch=89, lrate=0.300, error=13.318
# >epoch=90, lrate=0.300, error=13.246
# >epoch=91, lrate=0.300, error=13.175
# >epoch=92, lrate=0.300, error=13.107
# >epoch=93, lrate=0.300, error=13.039
# >epoch=94, lrate=0.300, error=12.974
# >epoch=95, lrate=0.300, error=12.910
# >epoch=96, lrate=0.300, error=12.847
# >epoch=97, lrate=0.300, error=12.786
# >epoch=98, lrate=0.300, error=12.726
# >epoch=99, lrate=0.300, error=12.667
# >epoch=100, lrate=0.300, error=12.610
# >epoch=101, lrate=0.300, error=12.553
# >epoch=102, lrate=0.300, error=12.498
# >epoch=103, lrate=0.300, error=12.444
# >epoch=104, lrate=0.300, error=12.391
# >epoch=105, lrate=0.300, error=12.340
# >epoch=106, lrate=0.300, error=12.289
# >epoch=107, lrate=0.300, error=12.239
# >epoch=108, lrate=0.300, error=12.189
# >epoch=109, lrate=0.300, error=12.141
# >epoch=110, lrate=0.300, error=12.094
# >epoch=111, lrate=0.300, error=12.047
# >epoch=112, lrate=0.300, error=12.001
# >epoch=113, lrate=0.300, error=11.956
# >epoch=114, lrate=0.300, error=11.912
# >epoch=115, lrate=0.300, error=11.869
# >epoch=116, lrate=0.300, error=11.826
# >epoch=117, lrate=0.300, error=11.783
# >epoch=118, lrate=0.300, error=11.742
# >epoch=119, lrate=0.300, error=11.701
# >epoch=120, lrate=0.300, error=11.661
# >epoch=121, lrate=0.300, error=11.621
# >epoch=122, lrate=0.300, error=11.582
# >epoch=123, lrate=0.300, error=11.543
# >epoch=124, lrate=0.300, error=11.505
# >epoch=125, lrate=0.300, error=11.467
# >epoch=126, lrate=0.300, error=11.430
# >epoch=127, lrate=0.300, error=11.394
# >epoch=128, lrate=0.300, error=11.358
# >epoch=129, lrate=0.300, error=11.322
# >epoch=130, lrate=0.300, error=11.287
# >epoch=131, lrate=0.300, error=11.253
# >epoch=132, lrate=0.300, error=11.219
# >epoch=133, lrate=0.300, error=11.185
# >epoch=134, lrate=0.300, error=11.152
# >epoch=135, lrate=0.300, error=11.119
# >epoch=136, lrate=0.300, error=11.087
# >epoch=137, lrate=0.300, error=11.054
# >epoch=138, lrate=0.300, error=11.023
# >epoch=139, lrate=0.300, error=10.992
# >epoch=140, lrate=0.300, error=10.961
# >epoch=141, lrate=0.300, error=10.930
# >epoch=142, lrate=0.300, error=10.900
# >epoch=143, lrate=0.300, error=10.870
# >epoch=144, lrate=0.300, error=10.841
# >epoch=145, lrate=0.300, error=10.812
# >epoch=146, lrate=0.300, error=10.783
# >epoch=147, lrate=0.300, error=10.755
# >epoch=148, lrate=0.300, error=10.727
# >epoch=149, lrate=0.300, error=10.699
# >epoch=150, lrate=0.300, error=10.672
# >epoch=151, lrate=0.300, error=10.645
# >epoch=152, lrate=0.300, error=10.618
# >epoch=153, lrate=0.300, error=10.591
# >epoch=154, lrate=0.300, error=10.565
# >epoch=155, lrate=0.300, error=10.539
# >epoch=156, lrate=0.300, error=10.514
# >epoch=157, lrate=0.300, error=10.489
# >epoch=158, lrate=0.300, error=10.464
# >epoch=159, lrate=0.300, error=10.439
# >epoch=160, lrate=0.300, error=10.414
# >epoch=161, lrate=0.300, error=10.390
# >epoch=162, lrate=0.300, error=10.366
# >epoch=163, lrate=0.300, error=10.343
# >epoch=164, lrate=0.300, error=10.319
# >epoch=165, lrate=0.300, error=10.296
# >epoch=166, lrate=0.300, error=10.273
# >epoch=167, lrate=0.300, error=10.250
# >epoch=168, lrate=0.300, error=10.228
# >epoch=169, lrate=0.300, error=10.206
# >epoch=170, lrate=0.300, error=10.184
# >epoch=171, lrate=0.300, error=10.162
# >epoch=172, lrate=0.300, error=10.141
# >epoch=173, lrate=0.300, error=10.120
# >epoch=174, lrate=0.300, error=10.099
# >epoch=175, lrate=0.300, error=10.078
# >epoch=176, lrate=0.300, error=10.057
# >epoch=177, lrate=0.300, error=10.037
# >epoch=178, lrate=0.300, error=10.017
# >epoch=179, lrate=0.300, error=9.997
# >epoch=180, lrate=0.300, error=9.977
# >epoch=181, lrate=0.300, error=9.958
# >epoch=182, lrate=0.300, error=9.938
# >epoch=183, lrate=0.300, error=9.919
# >epoch=184, lrate=0.300, error=9.900
# >epoch=185, lrate=0.300, error=9.882
# >epoch=186, lrate=0.300, error=9.863
# >epoch=187, lrate=0.300, error=9.845
# >epoch=188, lrate=0.300, error=9.827
# >epoch=189, lrate=0.300, error=9.809
# >epoch=190, lrate=0.300, error=9.791
# >epoch=191, lrate=0.300, error=9.773
# >epoch=192, lrate=0.300, error=9.756
# >epoch=193, lrate=0.300, error=9.738
# >epoch=194, lrate=0.300, error=9.721
# >epoch=195, lrate=0.300, error=9.704
# >epoch=196, lrate=0.300, error=9.688
# >epoch=197, lrate=0.300, error=9.671
# >epoch=198, lrate=0.300, error=9.654
# >epoch=199, lrate=0.300, error=9.638
# >epoch=200, lrate=0.300, error=9.622
# >epoch=201, lrate=0.300, error=9.606
# >epoch=202, lrate=0.300, error=9.590
# >epoch=203, lrate=0.300, error=9.574
# >epoch=204, lrate=0.300, error=9.559
# >epoch=205, lrate=0.300, error=9.544
# >epoch=206, lrate=0.300, error=9.528
# >epoch=207, lrate=0.300, error=9.513
# >epoch=208, lrate=0.300, error=9.498
# >epoch=209, lrate=0.300, error=9.483
# >epoch=210, lrate=0.300, error=9.469
# >epoch=211, lrate=0.300, error=9.454
# >epoch=212, lrate=0.300, error=9.440
# >epoch=213, lrate=0.300, error=9.425
# >epoch=214, lrate=0.300, error=9.411
# >epoch=215, lrate=0.300, error=9.397
# >epoch=216, lrate=0.300, error=9.383
# >epoch=217, lrate=0.300, error=9.369
# >epoch=218, lrate=0.300, error=9.356
# >epoch=219, lrate=0.300, error=9.342
# >epoch=220, lrate=0.300, error=9.328
# >epoch=221, lrate=0.300, error=9.315
# >epoch=222, lrate=0.300, error=9.302
# >epoch=223, lrate=0.300, error=9.289
# >epoch=224, lrate=0.300, error=9.276
# >epoch=225, lrate=0.300, error=9.263
# >epoch=226, lrate=0.300, error=9.250
# >epoch=227, lrate=0.300, error=9.237
# >epoch=228, lrate=0.300, error=9.225
# >epoch=229, lrate=0.300, error=9.212
# >epoch=230, lrate=0.300, error=9.200
# >epoch=231, lrate=0.300, error=9.188
# >epoch=232, lrate=0.300, error=9.175
# >epoch=233, lrate=0.300, error=9.163
# >epoch=234, lrate=0.300, error=9.151
# >epoch=235, lrate=0.300, error=9.139
# >epoch=236, lrate=0.300, error=9.128
# >epoch=237, lrate=0.300, error=9.116
# >epoch=238, lrate=0.300, error=9.104
# >epoch=239, lrate=0.300, error=9.093
# >epoch=240, lrate=0.300, error=9.081
# >epoch=241, lrate=0.300, error=9.070
# >epoch=242, lrate=0.300, error=9.059
# >epoch=243, lrate=0.300, error=9.047
# >epoch=244, lrate=0.300, error=9.036
# >epoch=245, lrate=0.300, error=9.025
# >epoch=246, lrate=0.300, error=9.014
# >epoch=247, lrate=0.300, error=9.004
# >epoch=248, lrate=0.300, error=8.993
# >epoch=249, lrate=0.300, error=8.982
# >epoch=250, lrate=0.300, error=8.972
# >epoch=251, lrate=0.300, error=8.961
# >epoch=252, lrate=0.300, error=8.951
# >epoch=253, lrate=0.300, error=8.940
# >epoch=254, lrate=0.300, error=8.930
# >epoch=255, lrate=0.300, error=8.920
# >epoch=256, lrate=0.300, error=8.910
# >epoch=257, lrate=0.300, error=8.900
# >epoch=258, lrate=0.300, error=8.890
# >epoch=259, lrate=0.300, error=8.880
# >epoch=260, lrate=0.300, error=8.870
# >epoch=261, lrate=0.300, error=8.860
# >epoch=262, lrate=0.300, error=8.850
# >epoch=263, lrate=0.300, error=8.841
# >epoch=264, lrate=0.300, error=8.831
# >epoch=265, lrate=0.300, error=8.822
# >epoch=266, lrate=0.300, error=8.812
# >epoch=267, lrate=0.300, error=8.803
# >epoch=268, lrate=0.300, error=8.794
# >epoch=269, lrate=0.300, error=8.784
# >epoch=270, lrate=0.300, error=8.775
# >epoch=271, lrate=0.300, error=8.766
# >epoch=272, lrate=0.300, error=8.757
# >epoch=273, lrate=0.300, error=8.748
# >epoch=274, lrate=0.300, error=8.739
# >epoch=275, lrate=0.300, error=8.730
# >epoch=276, lrate=0.300, error=8.722
# >epoch=277, lrate=0.300, error=8.713
# >epoch=278, lrate=0.300, error=8.704
# >epoch=279, lrate=0.300, error=8.696
# >epoch=280, lrate=0.300, error=8.687
# >epoch=281, lrate=0.300, error=8.679
# >epoch=282, lrate=0.300, error=8.670
# >epoch=283, lrate=0.300, error=8.662
# >epoch=284, lrate=0.300, error=8.654
# >epoch=285, lrate=0.300, error=8.645
# >epoch=286, lrate=0.300, error=8.637
# >epoch=287, lrate=0.300, error=8.629
# >epoch=288, lrate=0.300, error=8.621
# >epoch=289, lrate=0.300, error=8.613
# >epoch=290, lrate=0.300, error=8.605
# >epoch=291, lrate=0.300, error=8.597
# >epoch=292, lrate=0.300, error=8.589
# >epoch=293, lrate=0.300, error=8.581
# >epoch=294, lrate=0.300, error=8.573
# >epoch=295, lrate=0.300, error=8.565
# >epoch=296, lrate=0.300, error=8.557
# >epoch=297, lrate=0.300, error=8.549
# >epoch=298, lrate=0.300, error=8.541
# >epoch=299, lrate=0.300, error=8.534
# >epoch=300, lrate=0.300, error=8.526
# >epoch=301, lrate=0.300, error=8.518
# >epoch=302, lrate=0.300, error=8.510
# >epoch=303, lrate=0.300, error=8.502
# >epoch=304, lrate=0.300, error=8.494
# >epoch=305, lrate=0.300, error=8.487
# >epoch=306, lrate=0.300, error=8.479
# >epoch=307, lrate=0.300, error=8.471
# >epoch=308, lrate=0.300, error=8.463
# >epoch=309, lrate=0.300, error=8.455
# >epoch=310, lrate=0.300, error=8.447
# >epoch=311, lrate=0.300, error=8.439
# >epoch=312, lrate=0.300, error=8.431
# >epoch=313, lrate=0.300, error=8.423
# >epoch=314, lrate=0.300, error=8.414
# >epoch=315, lrate=0.300, error=8.406
# >epoch=316, lrate=0.300, error=8.398
# >epoch=317, lrate=0.300, error=8.389
# >epoch=318, lrate=0.300, error=8.381
# >epoch=319, lrate=0.300, error=8.372
# >epoch=320, lrate=0.300, error=8.364
# >epoch=321, lrate=0.300, error=8.355
# >epoch=322, lrate=0.300, error=8.346
# >epoch=323, lrate=0.300, error=8.338
# >epoch=324, lrate=0.300, error=8.329
# >epoch=325, lrate=0.300, error=8.320
# >epoch=326, lrate=0.300, error=8.311
# >epoch=327, lrate=0.300, error=8.301
# >epoch=328, lrate=0.300, error=8.292
# >epoch=329, lrate=0.300, error=8.283
# >epoch=330, lrate=0.300, error=8.273
# >epoch=331, lrate=0.300, error=8.264
# >epoch=332, lrate=0.300, error=8.254
# >epoch=333, lrate=0.300, error=8.244
# >epoch=334, lrate=0.300, error=8.234
# >epoch=335, lrate=0.300, error=8.224
# >epoch=336, lrate=0.300, error=8.214
# >epoch=337, lrate=0.300, error=8.204
# >epoch=338, lrate=0.300, error=8.194
# >epoch=339, lrate=0.300, error=8.183
# >epoch=340, lrate=0.300, error=8.173
# >epoch=341, lrate=0.300, error=8.162
# >epoch=342, lrate=0.300, error=8.152
# >epoch=343, lrate=0.300, error=8.141
# >epoch=344, lrate=0.300, error=8.130
# >epoch=345, lrate=0.300, error=8.119
# >epoch=346, lrate=0.300, error=8.108
# >epoch=347, lrate=0.300, error=8.097
# >epoch=348, lrate=0.300, error=8.086
# >epoch=349, lrate=0.300, error=8.075
# >epoch=350, lrate=0.300, error=8.064
# >epoch=351, lrate=0.300, error=8.052
# >epoch=352, lrate=0.300, error=8.041
# >epoch=353, lrate=0.300, error=8.030
# >epoch=354, lrate=0.300, error=8.018
# >epoch=355, lrate=0.300, error=8.007
# >epoch=356, lrate=0.300, error=7.995
# >epoch=357, lrate=0.300, error=7.983
# >epoch=358, lrate=0.300, error=7.972
# >epoch=359, lrate=0.300, error=7.960
# >epoch=360, lrate=0.300, error=7.949
# >epoch=361, lrate=0.300, error=7.937
# >epoch=362, lrate=0.300, error=7.925
# >epoch=363, lrate=0.300, error=7.913
# >epoch=364, lrate=0.300, error=7.902
# >epoch=365, lrate=0.300, error=7.890
# >epoch=366, lrate=0.300, error=7.878
# >epoch=367, lrate=0.300, error=7.867
# >epoch=368, lrate=0.300, error=7.855
# >epoch=369, lrate=0.300, error=7.843
# >epoch=370, lrate=0.300, error=7.832
# >epoch=371, lrate=0.300, error=7.820
# >epoch=372, lrate=0.300, error=7.808
# >epoch=373, lrate=0.300, error=7.797
# >epoch=374, lrate=0.300, error=7.785
# >epoch=375, lrate=0.300, error=7.774
# >epoch=376, lrate=0.300, error=7.762
# >epoch=377, lrate=0.300, error=7.751
# >epoch=378, lrate=0.300, error=7.739
# >epoch=379, lrate=0.300, error=7.728
# >epoch=380, lrate=0.300, error=7.716
# >epoch=381, lrate=0.300, error=7.705
# >epoch=382, lrate=0.300, error=7.694
# >epoch=383, lrate=0.300, error=7.682
# >epoch=384, lrate=0.300, error=7.671
# >epoch=385, lrate=0.300, error=7.660
# >epoch=386, lrate=0.300, error=7.649
# >epoch=387, lrate=0.300, error=7.638
# >epoch=388, lrate=0.300, error=7.627
# >epoch=389, lrate=0.300, error=7.616
# >epoch=390, lrate=0.300, error=7.605
# >epoch=391, lrate=0.300, error=7.594
# >epoch=392, lrate=0.300, error=7.583
# >epoch=393, lrate=0.300, error=7.572
# >epoch=394, lrate=0.300, error=7.562
# >epoch=395, lrate=0.300, error=7.551
# >epoch=396, lrate=0.300, error=7.540
# >epoch=397, lrate=0.300, error=7.530
# >epoch=398, lrate=0.300, error=7.519
# >epoch=399, lrate=0.300, error=7.508
# >epoch=400, lrate=0.300, error=7.498
# >epoch=401, lrate=0.300, error=7.488
# >epoch=402, lrate=0.300, error=7.477
# >epoch=403, lrate=0.300, error=7.467
# >epoch=404, lrate=0.300, error=7.457
# >epoch=405, lrate=0.300, error=7.446
# >epoch=406, lrate=0.300, error=7.436
# >epoch=407, lrate=0.300, error=7.426
# >epoch=408, lrate=0.300, error=7.416
# >epoch=409, lrate=0.300, error=7.406
# >epoch=410, lrate=0.300, error=7.396
# >epoch=411, lrate=0.300, error=7.385
# >epoch=412, lrate=0.300, error=7.375
# >epoch=413, lrate=0.300, error=7.366
# >epoch=414, lrate=0.300, error=7.356
# >epoch=415, lrate=0.300, error=7.346
# >epoch=416, lrate=0.300, error=7.336
# >epoch=417, lrate=0.300, error=7.326
# >epoch=418, lrate=0.300, error=7.316
# >epoch=419, lrate=0.300, error=7.306
# >epoch=420, lrate=0.300, error=7.297
# >epoch=421, lrate=0.300, error=7.287
# >epoch=422, lrate=0.300, error=7.277
# >epoch=423, lrate=0.300, error=7.267
# >epoch=424, lrate=0.300, error=7.258
# >epoch=425, lrate=0.300, error=7.248
# >epoch=426, lrate=0.300, error=7.239
# >epoch=427, lrate=0.300, error=7.229
# >epoch=428, lrate=0.300, error=7.219
# >epoch=429, lrate=0.300, error=7.210
# >epoch=430, lrate=0.300, error=7.200
# >epoch=431, lrate=0.300, error=7.191
# >epoch=432, lrate=0.300, error=7.181
# >epoch=433, lrate=0.300, error=7.172
# >epoch=434, lrate=0.300, error=7.162
# >epoch=435, lrate=0.300, error=7.153
# >epoch=436, lrate=0.300, error=7.144
# >epoch=437, lrate=0.300, error=7.134
# >epoch=438, lrate=0.300, error=7.125
# >epoch=439, lrate=0.300, error=7.115
# >epoch=440, lrate=0.300, error=7.106
# >epoch=441, lrate=0.300, error=7.097
# >epoch=442, lrate=0.300, error=7.088
# >epoch=443, lrate=0.300, error=7.078
# >epoch=444, lrate=0.300, error=7.069
# >epoch=445, lrate=0.300, error=7.060
# >epoch=446, lrate=0.300, error=7.051
# >epoch=447, lrate=0.300, error=7.041
# >epoch=448, lrate=0.300, error=7.032
# >epoch=449, lrate=0.300, error=7.023
# >epoch=450, lrate=0.300, error=7.014
# >epoch=451, lrate=0.300, error=7.005
# >epoch=452, lrate=0.300, error=6.996
# >epoch=453, lrate=0.300, error=6.986
# >epoch=454, lrate=0.300, error=6.977
# >epoch=455, lrate=0.300, error=6.968
# >epoch=456, lrate=0.300, error=6.959
# >epoch=457, lrate=0.300, error=6.950
# >epoch=458, lrate=0.300, error=6.941
# >epoch=459, lrate=0.300, error=6.932
# >epoch=460, lrate=0.300, error=6.923
# >epoch=461, lrate=0.300, error=6.914
# >epoch=462, lrate=0.300, error=6.905
# >epoch=463, lrate=0.300, error=6.896
# >epoch=464, lrate=0.300, error=6.888
# >epoch=465, lrate=0.300, error=6.879
# >epoch=466, lrate=0.300, error=6.870
# >epoch=467, lrate=0.300, error=6.861
# >epoch=468, lrate=0.300, error=6.852
# >epoch=469, lrate=0.300, error=6.843
# >epoch=470, lrate=0.300, error=6.835
# >epoch=471, lrate=0.300, error=6.826
# >epoch=472, lrate=0.300, error=6.817
# >epoch=473, lrate=0.300, error=6.809
# >epoch=474, lrate=0.300, error=6.800
# >epoch=475, lrate=0.300, error=6.791
# >epoch=476, lrate=0.300, error=6.783
# >epoch=477, lrate=0.300, error=6.774
# >epoch=478, lrate=0.300, error=6.766
# >epoch=479, lrate=0.300, error=6.757
# >epoch=480, lrate=0.300, error=6.749
# >epoch=481, lrate=0.300, error=6.740
# >epoch=482, lrate=0.300, error=6.732
# >epoch=483, lrate=0.300, error=6.723
# >epoch=484, lrate=0.300, error=6.715
# >epoch=485, lrate=0.300, error=6.707
# >epoch=486, lrate=0.300, error=6.698
# >epoch=487, lrate=0.300, error=6.690
# >epoch=488, lrate=0.300, error=6.682
# >epoch=489, lrate=0.300, error=6.673
# >epoch=490, lrate=0.300, error=6.665
# >epoch=491, lrate=0.300, error=6.657
# >epoch=492, lrate=0.300, error=6.649
# >epoch=493, lrate=0.300, error=6.641
# >epoch=494, lrate=0.300, error=6.633
# >epoch=495, lrate=0.300, error=6.625
# >epoch=496, lrate=0.300, error=6.617
# >epoch=497, lrate=0.300, error=6.609
# >epoch=498, lrate=0.300, error=6.601
# >epoch=499, lrate=0.300, error=6.593
# >epoch=0, lrate=0.300, error=141.996
# >epoch=1, lrate=0.300, error=110.352
# >epoch=2, lrate=0.300, error=103.130
# >epoch=3, lrate=0.300, error=92.147
# >epoch=4, lrate=0.300, error=80.975
# >epoch=5, lrate=0.300, error=72.725
# >epoch=6, lrate=0.300, error=66.971
# >epoch=7, lrate=0.300, error=62.476
# >epoch=8, lrate=0.300, error=58.436
# >epoch=9, lrate=0.300, error=54.472
# >epoch=10, lrate=0.300, error=50.489
# >epoch=11, lrate=0.300, error=46.551
# >epoch=12, lrate=0.300, error=42.788
# >epoch=13, lrate=0.300, error=39.326
# >epoch=14, lrate=0.300, error=36.248
# >epoch=15, lrate=0.300, error=33.578
# >epoch=16, lrate=0.300, error=31.295
# >epoch=17, lrate=0.300, error=29.357
# >epoch=18, lrate=0.300, error=27.715
# >epoch=19, lrate=0.300, error=26.320
# >epoch=20, lrate=0.300, error=25.128
# >epoch=21, lrate=0.300, error=24.104
# >epoch=22, lrate=0.300, error=23.216
# >epoch=23, lrate=0.300, error=22.441
# >epoch=24, lrate=0.300, error=21.760
# >epoch=25, lrate=0.300, error=21.156
# >epoch=26, lrate=0.300, error=20.617
# >epoch=27, lrate=0.300, error=20.133
# >epoch=28, lrate=0.300, error=19.695
# >epoch=29, lrate=0.300, error=19.297
# >epoch=30, lrate=0.300, error=18.932
# >epoch=31, lrate=0.300, error=18.598
# >epoch=32, lrate=0.300, error=18.289
# >epoch=33, lrate=0.300, error=18.003
# >epoch=34, lrate=0.300, error=17.737
# >epoch=35, lrate=0.300, error=17.488
# >epoch=36, lrate=0.300, error=17.255
# >epoch=37, lrate=0.300, error=17.037
# >epoch=38, lrate=0.300, error=16.831
# >epoch=39, lrate=0.300, error=16.637
# >epoch=40, lrate=0.300, error=16.453
# >epoch=41, lrate=0.300, error=16.279
# >epoch=42, lrate=0.300, error=16.114
# >epoch=43, lrate=0.300, error=15.956
# >epoch=44, lrate=0.300, error=15.807
# >epoch=45, lrate=0.300, error=15.664
# >epoch=46, lrate=0.300, error=15.527
# >epoch=47, lrate=0.300, error=15.397
# >epoch=48, lrate=0.300, error=15.272
# >epoch=49, lrate=0.300, error=15.152
# >epoch=50, lrate=0.300, error=15.037
# >epoch=51, lrate=0.300, error=14.926
# >epoch=52, lrate=0.300, error=14.820
# >epoch=53, lrate=0.300, error=14.718
# >epoch=54, lrate=0.300, error=14.620
# >epoch=55, lrate=0.300, error=14.525
# >epoch=56, lrate=0.300, error=14.434
# >epoch=57, lrate=0.300, error=14.346
# >epoch=58, lrate=0.300, error=14.261
# >epoch=59, lrate=0.300, error=14.179
# >epoch=60, lrate=0.300, error=14.100
# >epoch=61, lrate=0.300, error=14.023
# >epoch=62, lrate=0.300, error=13.949
# >epoch=63, lrate=0.300, error=13.877
# >epoch=64, lrate=0.300, error=13.807
# >epoch=65, lrate=0.300, error=13.740
# >epoch=66, lrate=0.300, error=13.675
# >epoch=67, lrate=0.300, error=13.611
# >epoch=68, lrate=0.300, error=13.550
# >epoch=69, lrate=0.300, error=13.490
# >epoch=70, lrate=0.300, error=13.432
# >epoch=71, lrate=0.300, error=13.375
# >epoch=72, lrate=0.300, error=13.321
# >epoch=73, lrate=0.300, error=13.267
# >epoch=74, lrate=0.300, error=13.215
# >epoch=75, lrate=0.300, error=13.165
# >epoch=76, lrate=0.300, error=13.115
# >epoch=77, lrate=0.300, error=13.067
# >epoch=78, lrate=0.300, error=13.021
# >epoch=79, lrate=0.300, error=12.975
# >epoch=80, lrate=0.300, error=12.930
# >epoch=81, lrate=0.300, error=12.887
# >epoch=82, lrate=0.300, error=12.845
# >epoch=83, lrate=0.300, error=12.803
# >epoch=84, lrate=0.300, error=12.763
# >epoch=85, lrate=0.300, error=12.723
# >epoch=86, lrate=0.300, error=12.684
# >epoch=87, lrate=0.300, error=12.646
# >epoch=88, lrate=0.300, error=12.609
# >epoch=89, lrate=0.300, error=12.573
# >epoch=90, lrate=0.300, error=12.537
# >epoch=91, lrate=0.300, error=12.502
# >epoch=92, lrate=0.300, error=12.468
# >epoch=93, lrate=0.300, error=12.435
# >epoch=94, lrate=0.300, error=12.402
# >epoch=95, lrate=0.300, error=12.369
# >epoch=96, lrate=0.300, error=12.338
# >epoch=97, lrate=0.300, error=12.307
# >epoch=98, lrate=0.300, error=12.276
# >epoch=99, lrate=0.300, error=12.246
# >epoch=100, lrate=0.300, error=12.216
# >epoch=101, lrate=0.300, error=12.187
# >epoch=102, lrate=0.300, error=12.159
# >epoch=103, lrate=0.300, error=12.131
# >epoch=104, lrate=0.300, error=12.103
# >epoch=105, lrate=0.300, error=12.076
# >epoch=106, lrate=0.300, error=12.049
# >epoch=107, lrate=0.300, error=12.023
# >epoch=108, lrate=0.300, error=11.997
# >epoch=109, lrate=0.300, error=11.971
# >epoch=110, lrate=0.300, error=11.945
# >epoch=111, lrate=0.300, error=11.920
# >epoch=112, lrate=0.300, error=11.896
# >epoch=113, lrate=0.300, error=11.871
# >epoch=114, lrate=0.300, error=11.847
# >epoch=115, lrate=0.300, error=11.824
# >epoch=116, lrate=0.300, error=11.800
# >epoch=117, lrate=0.300, error=11.777
# >epoch=118, lrate=0.300, error=11.754
# >epoch=119, lrate=0.300, error=11.731
# >epoch=120, lrate=0.300, error=11.709
# >epoch=121, lrate=0.300, error=11.686
# >epoch=122, lrate=0.300, error=11.664
# >epoch=123, lrate=0.300, error=11.642
# >epoch=124, lrate=0.300, error=11.621
# >epoch=125, lrate=0.300, error=11.599
# >epoch=126, lrate=0.300, error=11.578
# >epoch=127, lrate=0.300, error=11.557
# >epoch=128, lrate=0.300, error=11.536
# >epoch=129, lrate=0.300, error=11.515
# >epoch=130, lrate=0.300, error=11.495
# >epoch=131, lrate=0.300, error=11.474
# >epoch=132, lrate=0.300, error=11.454
# >epoch=133, lrate=0.300, error=11.434
# >epoch=134, lrate=0.300, error=11.414
# >epoch=135, lrate=0.300, error=11.394
# >epoch=136, lrate=0.300, error=11.374
# >epoch=137, lrate=0.300, error=11.354
# >epoch=138, lrate=0.300, error=11.334
# >epoch=139, lrate=0.300, error=11.315
# >epoch=140, lrate=0.300, error=11.295
# >epoch=141, lrate=0.300, error=11.276
# >epoch=142, lrate=0.300, error=11.257
# >epoch=143, lrate=0.300, error=11.237
# >epoch=144, lrate=0.300, error=11.218
# >epoch=145, lrate=0.300, error=11.199
# >epoch=146, lrate=0.300, error=11.180
# >epoch=147, lrate=0.300, error=11.161
# >epoch=148, lrate=0.300, error=11.142
# >epoch=149, lrate=0.300, error=11.123
# >epoch=150, lrate=0.300, error=11.104
# >epoch=151, lrate=0.300, error=11.085
# >epoch=152, lrate=0.300, error=11.066
# >epoch=153, lrate=0.300, error=11.047
# >epoch=154, lrate=0.300, error=11.028
# >epoch=155, lrate=0.300, error=11.009
# >epoch=156, lrate=0.300, error=10.990
# >epoch=157, lrate=0.300, error=10.971
# >epoch=158, lrate=0.300, error=10.952
# >epoch=159, lrate=0.300, error=10.933
# >epoch=160, lrate=0.300, error=10.914
# >epoch=161, lrate=0.300, error=10.895
# >epoch=162, lrate=0.300, error=10.876
# >epoch=163, lrate=0.300, error=10.856
# >epoch=164, lrate=0.300, error=10.837
# >epoch=165, lrate=0.300, error=10.818
# >epoch=166, lrate=0.300, error=10.798
# >epoch=167, lrate=0.300, error=10.779
# >epoch=168, lrate=0.300, error=10.759
# >epoch=169, lrate=0.300, error=10.739
# >epoch=170, lrate=0.300, error=10.719
# >epoch=171, lrate=0.300, error=10.700
# >epoch=172, lrate=0.300, error=10.679
# >epoch=173, lrate=0.300, error=10.659
# >epoch=174, lrate=0.300, error=10.639
# >epoch=175, lrate=0.300, error=10.619
# >epoch=176, lrate=0.300, error=10.598
# >epoch=177, lrate=0.300, error=10.577
# >epoch=178, lrate=0.300, error=10.556
# >epoch=179, lrate=0.300, error=10.535
# >epoch=180, lrate=0.300, error=10.514
# >epoch=181, lrate=0.300, error=10.493
# >epoch=182, lrate=0.300, error=10.472
# >epoch=183, lrate=0.300, error=10.450
# >epoch=184, lrate=0.300, error=10.428
# >epoch=185, lrate=0.300, error=10.406
# >epoch=186, lrate=0.300, error=10.384
# >epoch=187, lrate=0.300, error=10.362
# >epoch=188, lrate=0.300, error=10.340
# >epoch=189, lrate=0.300, error=10.318
# >epoch=190, lrate=0.300, error=10.295
# >epoch=191, lrate=0.300, error=10.272
# >epoch=192, lrate=0.300, error=10.250
# >epoch=193, lrate=0.300, error=10.227
# >epoch=194, lrate=0.300, error=10.204
# >epoch=195, lrate=0.300, error=10.181
# >epoch=196, lrate=0.300, error=10.158
# >epoch=197, lrate=0.300, error=10.134
# >epoch=198, lrate=0.300, error=10.111
# >epoch=199, lrate=0.300, error=10.088
# >epoch=200, lrate=0.300, error=10.065
# >epoch=201, lrate=0.300, error=10.041
# >epoch=202, lrate=0.300, error=10.018
# >epoch=203, lrate=0.300, error=9.995
# >epoch=204, lrate=0.300, error=9.971
# >epoch=205, lrate=0.300, error=9.948
# >epoch=206, lrate=0.300, error=9.925
# >epoch=207, lrate=0.300, error=9.901
# >epoch=208, lrate=0.300, error=9.878
# >epoch=209, lrate=0.300, error=9.855
# >epoch=210, lrate=0.300, error=9.832
# >epoch=211, lrate=0.300, error=9.809
# >epoch=212, lrate=0.300, error=9.786
# >epoch=213, lrate=0.300, error=9.763
# >epoch=214, lrate=0.300, error=9.740
# >epoch=215, lrate=0.300, error=9.717
# >epoch=216, lrate=0.300, error=9.695
# >epoch=217, lrate=0.300, error=9.672
# >epoch=218, lrate=0.300, error=9.650
# >epoch=219, lrate=0.300, error=9.627
# >epoch=220, lrate=0.300, error=9.605
# >epoch=221, lrate=0.300, error=9.583
# >epoch=222, lrate=0.300, error=9.561
# >epoch=223, lrate=0.300, error=9.539
# >epoch=224, lrate=0.300, error=9.518
# >epoch=225, lrate=0.300, error=9.496
# >epoch=226, lrate=0.300, error=9.475
# >epoch=227, lrate=0.300, error=9.453
# >epoch=228, lrate=0.300, error=9.432
# >epoch=229, lrate=0.300, error=9.411
# >epoch=230, lrate=0.300, error=9.391
# >epoch=231, lrate=0.300, error=9.370
# >epoch=232, lrate=0.300, error=9.349
# >epoch=233, lrate=0.300, error=9.329
# >epoch=234, lrate=0.300, error=9.309
# >epoch=235, lrate=0.300, error=9.289
# >epoch=236, lrate=0.300, error=9.269
# >epoch=237, lrate=0.300, error=9.249
# >epoch=238, lrate=0.300, error=9.229
# >epoch=239, lrate=0.300, error=9.210
# >epoch=240, lrate=0.300, error=9.191
# >epoch=241, lrate=0.300, error=9.172
# >epoch=242, lrate=0.300, error=9.153
# >epoch=243, lrate=0.300, error=9.134
# >epoch=244, lrate=0.300, error=9.115
# >epoch=245, lrate=0.300, error=9.097
# >epoch=246, lrate=0.300, error=9.079
# >epoch=247, lrate=0.300, error=9.061
# >epoch=248, lrate=0.300, error=9.043
# >epoch=249, lrate=0.300, error=9.025
# >epoch=250, lrate=0.300, error=9.007
# >epoch=251, lrate=0.300, error=8.990
# >epoch=252, lrate=0.300, error=8.972
# >epoch=253, lrate=0.300, error=8.955
# >epoch=254, lrate=0.300, error=8.938
# >epoch=255, lrate=0.300, error=8.922
# >epoch=256, lrate=0.300, error=8.905
# >epoch=257, lrate=0.300, error=8.888
# >epoch=258, lrate=0.300, error=8.872
# >epoch=259, lrate=0.300, error=8.856
# >epoch=260, lrate=0.300, error=8.840
# >epoch=261, lrate=0.300, error=8.824
# >epoch=262, lrate=0.300, error=8.808
# >epoch=263, lrate=0.300, error=8.793
# >epoch=264, lrate=0.300, error=8.777
# >epoch=265, lrate=0.300, error=8.762
# >epoch=266, lrate=0.300, error=8.747
# >epoch=267, lrate=0.300, error=8.732
# >epoch=268, lrate=0.300, error=8.717
# >epoch=269, lrate=0.300, error=8.702
# >epoch=270, lrate=0.300, error=8.687
# >epoch=271, lrate=0.300, error=8.673
# >epoch=272, lrate=0.300, error=8.659
# >epoch=273, lrate=0.300, error=8.644
# >epoch=274, lrate=0.300, error=8.630
# >epoch=275, lrate=0.300, error=8.616
# >epoch=276, lrate=0.300, error=8.603
# >epoch=277, lrate=0.300, error=8.589
# >epoch=278, lrate=0.300, error=8.575
# >epoch=279, lrate=0.300, error=8.562
# >epoch=280, lrate=0.300, error=8.549
# >epoch=281, lrate=0.300, error=8.535
# >epoch=282, lrate=0.300, error=8.522
# >epoch=283, lrate=0.300, error=8.509
# >epoch=284, lrate=0.300, error=8.497
# >epoch=285, lrate=0.300, error=8.484
# >epoch=286, lrate=0.300, error=8.471
# >epoch=287, lrate=0.300, error=8.459
# >epoch=288, lrate=0.300, error=8.446
# >epoch=289, lrate=0.300, error=8.434
# >epoch=290, lrate=0.300, error=8.422
# >epoch=291, lrate=0.300, error=8.410
# >epoch=292, lrate=0.300, error=8.398
# >epoch=293, lrate=0.300, error=8.386
# >epoch=294, lrate=0.300, error=8.374
# >epoch=295, lrate=0.300, error=8.362
# >epoch=296, lrate=0.300, error=8.351
# >epoch=297, lrate=0.300, error=8.339
# >epoch=298, lrate=0.300, error=8.328
# >epoch=299, lrate=0.300, error=8.317
# >epoch=300, lrate=0.300, error=8.305
# >epoch=301, lrate=0.300, error=8.294
# >epoch=302, lrate=0.300, error=8.283
# >epoch=303, lrate=0.300, error=8.272
# >epoch=304, lrate=0.300, error=8.261
# >epoch=305, lrate=0.300, error=8.251
# >epoch=306, lrate=0.300, error=8.240
# >epoch=307, lrate=0.300, error=8.229
# >epoch=308, lrate=0.300, error=8.219
# >epoch=309, lrate=0.300, error=8.208
# >epoch=310, lrate=0.300, error=8.198
# >epoch=311, lrate=0.300, error=8.188
# >epoch=312, lrate=0.300, error=8.178
# >epoch=313, lrate=0.300, error=8.167
# >epoch=314, lrate=0.300, error=8.157
# >epoch=315, lrate=0.300, error=8.147
# >epoch=316, lrate=0.300, error=8.137
# >epoch=317, lrate=0.300, error=8.128
# >epoch=318, lrate=0.300, error=8.118
# >epoch=319, lrate=0.300, error=8.108
# >epoch=320, lrate=0.300, error=8.099
# >epoch=321, lrate=0.300, error=8.089
# >epoch=322, lrate=0.300, error=8.080
# >epoch=323, lrate=0.300, error=8.070
# >epoch=324, lrate=0.300, error=8.061
# >epoch=325, lrate=0.300, error=8.052
# >epoch=326, lrate=0.300, error=8.043
# >epoch=327, lrate=0.300, error=8.033
# >epoch=328, lrate=0.300, error=8.024
# >epoch=329, lrate=0.300, error=8.015
# >epoch=330, lrate=0.300, error=8.007
# >epoch=331, lrate=0.300, error=7.998
# >epoch=332, lrate=0.300, error=7.989
# >epoch=333, lrate=0.300, error=7.980
# >epoch=334, lrate=0.300, error=7.972
# >epoch=335, lrate=0.300, error=7.963
# >epoch=336, lrate=0.300, error=7.955
# >epoch=337, lrate=0.300, error=7.946
# >epoch=338, lrate=0.300, error=7.938
# >epoch=339, lrate=0.300, error=7.929
# >epoch=340, lrate=0.300, error=7.921
# >epoch=341, lrate=0.300, error=7.913
# >epoch=342, lrate=0.300, error=7.905
# >epoch=343, lrate=0.300, error=7.897
# >epoch=344, lrate=0.300, error=7.889
# >epoch=345, lrate=0.300, error=7.881
# >epoch=346, lrate=0.300, error=7.873
# >epoch=347, lrate=0.300, error=7.865
# >epoch=348, lrate=0.300, error=7.858
# >epoch=349, lrate=0.300, error=7.850
# >epoch=350, lrate=0.300, error=7.842
# >epoch=351, lrate=0.300, error=7.835
# >epoch=352, lrate=0.300, error=7.827
# >epoch=353, lrate=0.300, error=7.820
# >epoch=354, lrate=0.300, error=7.812
# >epoch=355, lrate=0.300, error=7.805
# >epoch=356, lrate=0.300, error=7.798
# >epoch=357, lrate=0.300, error=7.790
# >epoch=358, lrate=0.300, error=7.783
# >epoch=359, lrate=0.300, error=7.776
# >epoch=360, lrate=0.300, error=7.769
# >epoch=361, lrate=0.300, error=7.762
# >epoch=362, lrate=0.300, error=7.755
# >epoch=363, lrate=0.300, error=7.748
# >epoch=364, lrate=0.300, error=7.741
# >epoch=365, lrate=0.300, error=7.734
# >epoch=366, lrate=0.300, error=7.727
# >epoch=367, lrate=0.300, error=7.720
# >epoch=368, lrate=0.300, error=7.713
# >epoch=369, lrate=0.300, error=7.707
# >epoch=370, lrate=0.300, error=7.700
# >epoch=371, lrate=0.300, error=7.693
# >epoch=372, lrate=0.300, error=7.686
# >epoch=373, lrate=0.300, error=7.679
# >epoch=374, lrate=0.300, error=7.672
# >epoch=375, lrate=0.300, error=7.665
# >epoch=376, lrate=0.300, error=7.659
# >epoch=377, lrate=0.300, error=7.652
# >epoch=378, lrate=0.300, error=7.645
# >epoch=379, lrate=0.300, error=7.637
# >epoch=380, lrate=0.300, error=7.630
# >epoch=381, lrate=0.300, error=7.623
# >epoch=382, lrate=0.300, error=7.616
# >epoch=383, lrate=0.300, error=7.608
# >epoch=384, lrate=0.300, error=7.600
# >epoch=385, lrate=0.300, error=7.593
# >epoch=386, lrate=0.300, error=7.585
# >epoch=387, lrate=0.300, error=7.576
# >epoch=388, lrate=0.300, error=7.568
# >epoch=389, lrate=0.300, error=7.559
# >epoch=390, lrate=0.300, error=7.551
# >epoch=391, lrate=0.300, error=7.541
# >epoch=392, lrate=0.300, error=7.532
# >epoch=393, lrate=0.300, error=7.522
# >epoch=394, lrate=0.300, error=7.513
# >epoch=395, lrate=0.300, error=7.502
# >epoch=396, lrate=0.300, error=7.492
# >epoch=397, lrate=0.300, error=7.481
# >epoch=398, lrate=0.300, error=7.470
# >epoch=399, lrate=0.300, error=7.459
# >epoch=400, lrate=0.300, error=7.448
# >epoch=401, lrate=0.300, error=7.436
# >epoch=402, lrate=0.300, error=7.424
# >epoch=403, lrate=0.300, error=7.412
# >epoch=404, lrate=0.300, error=7.399
# >epoch=405, lrate=0.300, error=7.387
# >epoch=406, lrate=0.300, error=7.374
# >epoch=407, lrate=0.300, error=7.361
# >epoch=408, lrate=0.300, error=7.348
# >epoch=409, lrate=0.300, error=7.334
# >epoch=410, lrate=0.300, error=7.321
# >epoch=411, lrate=0.300, error=7.307
# >epoch=412, lrate=0.300, error=7.294
# >epoch=413, lrate=0.300, error=7.280
# >epoch=414, lrate=0.300, error=7.266
# >epoch=415, lrate=0.300, error=7.252
# >epoch=416, lrate=0.300, error=7.238
# >epoch=417, lrate=0.300, error=7.224
# >epoch=418, lrate=0.300, error=7.210
# >epoch=419, lrate=0.300, error=7.196
# >epoch=420, lrate=0.300, error=7.181
# >epoch=421, lrate=0.300, error=7.167
# >epoch=422, lrate=0.300, error=7.153
# >epoch=423, lrate=0.300, error=7.139
# >epoch=424, lrate=0.300, error=7.125
# >epoch=425, lrate=0.300, error=7.110
# >epoch=426, lrate=0.300, error=7.096
# >epoch=427, lrate=0.300, error=7.082
# >epoch=428, lrate=0.300, error=7.068
# >epoch=429, lrate=0.300, error=7.053
# >epoch=430, lrate=0.300, error=7.039
# >epoch=431, lrate=0.300, error=7.025
# >epoch=432, lrate=0.300, error=7.011
# >epoch=433, lrate=0.300, error=6.997
# >epoch=434, lrate=0.300, error=6.983
# >epoch=435, lrate=0.300, error=6.969
# >epoch=436, lrate=0.300, error=6.955
# >epoch=437, lrate=0.300, error=6.941
# >epoch=438, lrate=0.300, error=6.928
# >epoch=439, lrate=0.300, error=6.914
# >epoch=440, lrate=0.300, error=6.900
# >epoch=441, lrate=0.300, error=6.887
# >epoch=442, lrate=0.300, error=6.873
# >epoch=443, lrate=0.300, error=6.859
# >epoch=444, lrate=0.300, error=6.846
# >epoch=445, lrate=0.300, error=6.833
# >epoch=446, lrate=0.300, error=6.819
# >epoch=447, lrate=0.300, error=6.806
# >epoch=448, lrate=0.300, error=6.793
# >epoch=449, lrate=0.300, error=6.780
# >epoch=450, lrate=0.300, error=6.767
# >epoch=451, lrate=0.300, error=6.753
# >epoch=452, lrate=0.300, error=6.741
# >epoch=453, lrate=0.300, error=6.728
# >epoch=454, lrate=0.300, error=6.715
# >epoch=455, lrate=0.300, error=6.702
# >epoch=456, lrate=0.300, error=6.689
# >epoch=457, lrate=0.300, error=6.677
# >epoch=458, lrate=0.300, error=6.664
# >epoch=459, lrate=0.300, error=6.652
# >epoch=460, lrate=0.300, error=6.639
# >epoch=461, lrate=0.300, error=6.627
# >epoch=462, lrate=0.300, error=6.615
# >epoch=463, lrate=0.300, error=6.603
# >epoch=464, lrate=0.300, error=6.591
# >epoch=465, lrate=0.300, error=6.579
# >epoch=466, lrate=0.300, error=6.567
# >epoch=467, lrate=0.300, error=6.555
# >epoch=468, lrate=0.300, error=6.543
# >epoch=469, lrate=0.300, error=6.531
# >epoch=470, lrate=0.300, error=6.520
# >epoch=471, lrate=0.300, error=6.508
# >epoch=472, lrate=0.300, error=6.496
# >epoch=473, lrate=0.300, error=6.485
# >epoch=474, lrate=0.300, error=6.474
# >epoch=475, lrate=0.300, error=6.462
# >epoch=476, lrate=0.300, error=6.451
# >epoch=477, lrate=0.300, error=6.440
# >epoch=478, lrate=0.300, error=6.429
# >epoch=479, lrate=0.300, error=6.418
# >epoch=480, lrate=0.300, error=6.407
# >epoch=481, lrate=0.300, error=6.396
# >epoch=482, lrate=0.300, error=6.385
# >epoch=483, lrate=0.300, error=6.374
# >epoch=484, lrate=0.300, error=6.364
# >epoch=485, lrate=0.300, error=6.353
# >epoch=486, lrate=0.300, error=6.342
# >epoch=487, lrate=0.300, error=6.332
# >epoch=488, lrate=0.300, error=6.321
# >epoch=489, lrate=0.300, error=6.311
# >epoch=490, lrate=0.300, error=6.301
# >epoch=491, lrate=0.300, error=6.290
# >epoch=492, lrate=0.300, error=6.280
# >epoch=493, lrate=0.300, error=6.270
# >epoch=494, lrate=0.300, error=6.260
# >epoch=495, lrate=0.300, error=6.250
# >epoch=496, lrate=0.300, error=6.240
# >epoch=497, lrate=0.300, error=6.230
# >epoch=498, lrate=0.300, error=6.220
# >epoch=499, lrate=0.300, error=6.211
# >epoch=0, lrate=0.300, error=132.494
# >epoch=1, lrate=0.300, error=111.814
# >epoch=2, lrate=0.300, error=108.565
# >epoch=3, lrate=0.300, error=103.114
# >epoch=4, lrate=0.300, error=94.259
# >epoch=5, lrate=0.300, error=83.237
# >epoch=6, lrate=0.300, error=73.285
# >epoch=7, lrate=0.300, error=65.596
# >epoch=8, lrate=0.300, error=59.481
# >epoch=9, lrate=0.300, error=54.221
# >epoch=10, lrate=0.300, error=49.531
# >epoch=11, lrate=0.300, error=45.403
# >epoch=12, lrate=0.300, error=41.885
# >epoch=13, lrate=0.300, error=38.971
# >epoch=14, lrate=0.300, error=36.587
# >epoch=15, lrate=0.300, error=34.634
# >epoch=16, lrate=0.300, error=33.017
# >epoch=17, lrate=0.300, error=31.657
# >epoch=18, lrate=0.300, error=30.494
# >epoch=19, lrate=0.300, error=29.482
# >epoch=20, lrate=0.300, error=28.590
# >epoch=21, lrate=0.300, error=27.792
# >epoch=22, lrate=0.300, error=27.071
# >epoch=23, lrate=0.300, error=26.413
# >epoch=24, lrate=0.300, error=25.808
# >epoch=25, lrate=0.300, error=25.248
# >epoch=26, lrate=0.300, error=24.726
# >epoch=27, lrate=0.300, error=24.237
# >epoch=28, lrate=0.300, error=23.778
# >epoch=29, lrate=0.300, error=23.344
# >epoch=30, lrate=0.300, error=22.933
# >epoch=31, lrate=0.300, error=22.544
# >epoch=32, lrate=0.300, error=22.172
# >epoch=33, lrate=0.300, error=21.819
# >epoch=34, lrate=0.300, error=21.480
# >epoch=35, lrate=0.300, error=21.156
# >epoch=36, lrate=0.300, error=20.846
# >epoch=37, lrate=0.300, error=20.547
# >epoch=38, lrate=0.300, error=20.260
# >epoch=39, lrate=0.300, error=19.984
# >epoch=40, lrate=0.300, error=19.718
# >epoch=41, lrate=0.300, error=19.461
# >epoch=42, lrate=0.300, error=19.213
# >epoch=43, lrate=0.300, error=18.973
# >epoch=44, lrate=0.300, error=18.742
# >epoch=45, lrate=0.300, error=18.518
# >epoch=46, lrate=0.300, error=18.301
# >epoch=47, lrate=0.300, error=18.092
# >epoch=48, lrate=0.300, error=17.889
# >epoch=49, lrate=0.300, error=17.692
# >epoch=50, lrate=0.300, error=17.502
# >epoch=51, lrate=0.300, error=17.318
# >epoch=52, lrate=0.300, error=17.140
# >epoch=53, lrate=0.300, error=16.967
# >epoch=54, lrate=0.300, error=16.799
# >epoch=55, lrate=0.300, error=16.637
# >epoch=56, lrate=0.300, error=16.480
# >epoch=57, lrate=0.300, error=16.328
# >epoch=58, lrate=0.300, error=16.180
# >epoch=59, lrate=0.300, error=16.037
# >epoch=60, lrate=0.300, error=15.898
# >epoch=61, lrate=0.300, error=15.763
# >epoch=62, lrate=0.300, error=15.632
# >epoch=63, lrate=0.300, error=15.504
# >epoch=64, lrate=0.300, error=15.381
# >epoch=65, lrate=0.300, error=15.260
# >epoch=66, lrate=0.300, error=15.143
# >epoch=67, lrate=0.300, error=15.029
# >epoch=68, lrate=0.300, error=14.919
# >epoch=69, lrate=0.300, error=14.811
# >epoch=70, lrate=0.300, error=14.705
# >epoch=71, lrate=0.300, error=14.603
# >epoch=72, lrate=0.300, error=14.503
# >epoch=73, lrate=0.300, error=14.405
# >epoch=74, lrate=0.300, error=14.310
# >epoch=75, lrate=0.300, error=14.217
# >epoch=76, lrate=0.300, error=14.126
# >epoch=77, lrate=0.300, error=14.037
# >epoch=78, lrate=0.300, error=13.950
# >epoch=79, lrate=0.300, error=13.864
# >epoch=80, lrate=0.300, error=13.781
# >epoch=81, lrate=0.300, error=13.699
# >epoch=82, lrate=0.300, error=13.619
# >epoch=83, lrate=0.300, error=13.541
# >epoch=84, lrate=0.300, error=13.464
# >epoch=85, lrate=0.300, error=13.389
# >epoch=86, lrate=0.300, error=13.315
# >epoch=87, lrate=0.300, error=13.243
# >epoch=88, lrate=0.300, error=13.172
# >epoch=89, lrate=0.300, error=13.102
# >epoch=90, lrate=0.300, error=13.033
# >epoch=91, lrate=0.300, error=12.966
# >epoch=92, lrate=0.300, error=12.900
# >epoch=93, lrate=0.300, error=12.835
# >epoch=94, lrate=0.300, error=12.771
# >epoch=95, lrate=0.300, error=12.709
# >epoch=96, lrate=0.300, error=12.647
# >epoch=97, lrate=0.300, error=12.586
# >epoch=98, lrate=0.300, error=12.527
# >epoch=99, lrate=0.300, error=12.468
# >epoch=100, lrate=0.300, error=12.411
# >epoch=101, lrate=0.300, error=12.354
# >epoch=102, lrate=0.300, error=12.298
# >epoch=103, lrate=0.300, error=12.244
# >epoch=104, lrate=0.300, error=12.190
# >epoch=105, lrate=0.300, error=12.136
# >epoch=106, lrate=0.300, error=12.084
# >epoch=107, lrate=0.300, error=12.033
# >epoch=108, lrate=0.300, error=11.982
# >epoch=109, lrate=0.300, error=11.932
# >epoch=110, lrate=0.300, error=11.883
# >epoch=111, lrate=0.300, error=11.835
# >epoch=112, lrate=0.300, error=11.787
# >epoch=113, lrate=0.300, error=11.740
# >epoch=114, lrate=0.300, error=11.694
# >epoch=115, lrate=0.300, error=11.648
# >epoch=116, lrate=0.300, error=11.603
# >epoch=117, lrate=0.300, error=11.559
# >epoch=118, lrate=0.300, error=11.515
# >epoch=119, lrate=0.300, error=11.472
# >epoch=120, lrate=0.300, error=11.430
# >epoch=121, lrate=0.300, error=11.388
# >epoch=122, lrate=0.300, error=11.347
# >epoch=123, lrate=0.300, error=11.306
# >epoch=124, lrate=0.300, error=11.266
# >epoch=125, lrate=0.300, error=11.227
# >epoch=126, lrate=0.300, error=11.188
# >epoch=127, lrate=0.300, error=11.150
# >epoch=128, lrate=0.300, error=11.112
# >epoch=129, lrate=0.300, error=11.075
# >epoch=130, lrate=0.300, error=11.038
# >epoch=131, lrate=0.300, error=11.001
# >epoch=132, lrate=0.300, error=10.966
# >epoch=133, lrate=0.300, error=10.930
# >epoch=134, lrate=0.300, error=10.895
# >epoch=135, lrate=0.300, error=10.861
# >epoch=136, lrate=0.300, error=10.827
# >epoch=137, lrate=0.300, error=10.793
# >epoch=138, lrate=0.300, error=10.760
# >epoch=139, lrate=0.300, error=10.728
# >epoch=140, lrate=0.300, error=10.696
# >epoch=141, lrate=0.300, error=10.664
# >epoch=142, lrate=0.300, error=10.632
# >epoch=143, lrate=0.300, error=10.601
# >epoch=144, lrate=0.300, error=10.571
# >epoch=145, lrate=0.300, error=10.541
# >epoch=146, lrate=0.300, error=10.511
# >epoch=147, lrate=0.300, error=10.481
# >epoch=148, lrate=0.300, error=10.452
# >epoch=149, lrate=0.300, error=10.424
# >epoch=150, lrate=0.300, error=10.395
# >epoch=151, lrate=0.300, error=10.367
# >epoch=152, lrate=0.300, error=10.340
# >epoch=153, lrate=0.300, error=10.312
# >epoch=154, lrate=0.300, error=10.285
# >epoch=155, lrate=0.300, error=10.259
# >epoch=156, lrate=0.300, error=10.232
# >epoch=157, lrate=0.300, error=10.206
# >epoch=158, lrate=0.300, error=10.181
# >epoch=159, lrate=0.300, error=10.155
# >epoch=160, lrate=0.300, error=10.130
# >epoch=161, lrate=0.300, error=10.105
# >epoch=162, lrate=0.300, error=10.081
# >epoch=163, lrate=0.300, error=10.056
# >epoch=164, lrate=0.300, error=10.032
# >epoch=165, lrate=0.300, error=10.009
# >epoch=166, lrate=0.300, error=9.985
# >epoch=167, lrate=0.300, error=9.962
# >epoch=168, lrate=0.300, error=9.939
# >epoch=169, lrate=0.300, error=9.917
# >epoch=170, lrate=0.300, error=9.894
# >epoch=171, lrate=0.300, error=9.872
# >epoch=172, lrate=0.300, error=9.850
# >epoch=173, lrate=0.300, error=9.829
# >epoch=174, lrate=0.300, error=9.807
# >epoch=175, lrate=0.300, error=9.786
# >epoch=176, lrate=0.300, error=9.765
# >epoch=177, lrate=0.300, error=9.744
# >epoch=178, lrate=0.300, error=9.724
# >epoch=179, lrate=0.300, error=9.703
# >epoch=180, lrate=0.300, error=9.683
# >epoch=181, lrate=0.300, error=9.663
# >epoch=182, lrate=0.300, error=9.644
# >epoch=183, lrate=0.300, error=9.624
# >epoch=184, lrate=0.300, error=9.605
# >epoch=185, lrate=0.300, error=9.586
# >epoch=186, lrate=0.300, error=9.567
# >epoch=187, lrate=0.300, error=9.548
# >epoch=188, lrate=0.300, error=9.529
# >epoch=189, lrate=0.300, error=9.511
# >epoch=190, lrate=0.300, error=9.493
# >epoch=191, lrate=0.300, error=9.475
# >epoch=192, lrate=0.300, error=9.457
# >epoch=193, lrate=0.300, error=9.439
# >epoch=194, lrate=0.300, error=9.422
# >epoch=195, lrate=0.300, error=9.404
# >epoch=196, lrate=0.300, error=9.387
# >epoch=197, lrate=0.300, error=9.370
# >epoch=198, lrate=0.300, error=9.353
# >epoch=199, lrate=0.300, error=9.336
# >epoch=200, lrate=0.300, error=9.320
# >epoch=201, lrate=0.300, error=9.303
# >epoch=202, lrate=0.300, error=9.287
# >epoch=203, lrate=0.300, error=9.271
# >epoch=204, lrate=0.300, error=9.255
# >epoch=205, lrate=0.300, error=9.239
# >epoch=206, lrate=0.300, error=9.223
# >epoch=207, lrate=0.300, error=9.208
# >epoch=208, lrate=0.300, error=9.192
# >epoch=209, lrate=0.300, error=9.177
# >epoch=210, lrate=0.300, error=9.161
# >epoch=211, lrate=0.300, error=9.146
# >epoch=212, lrate=0.300, error=9.131
# >epoch=213, lrate=0.300, error=9.116
# >epoch=214, lrate=0.300, error=9.102
# >epoch=215, lrate=0.300, error=9.087
# >epoch=216, lrate=0.300, error=9.073
# >epoch=217, lrate=0.300, error=9.058
# >epoch=218, lrate=0.300, error=9.044
# >epoch=219, lrate=0.300, error=9.030
# >epoch=220, lrate=0.300, error=9.015
# >epoch=221, lrate=0.300, error=9.001
# >epoch=222, lrate=0.300, error=8.988
# >epoch=223, lrate=0.300, error=8.974
# >epoch=224, lrate=0.300, error=8.960
# >epoch=225, lrate=0.300, error=8.946
# >epoch=226, lrate=0.300, error=8.933
# >epoch=227, lrate=0.300, error=8.919
# >epoch=228, lrate=0.300, error=8.906
# >epoch=229, lrate=0.300, error=8.893
# >epoch=230, lrate=0.300, error=8.880
# >epoch=231, lrate=0.300, error=8.867
# >epoch=232, lrate=0.300, error=8.854
# >epoch=233, lrate=0.300, error=8.841
# >epoch=234, lrate=0.300, error=8.828
# >epoch=235, lrate=0.300, error=8.815
# >epoch=236, lrate=0.300, error=8.803
# >epoch=237, lrate=0.300, error=8.790
# >epoch=238, lrate=0.300, error=8.778
# >epoch=239, lrate=0.300, error=8.765
# >epoch=240, lrate=0.300, error=8.753
# >epoch=241, lrate=0.300, error=8.741
# >epoch=242, lrate=0.300, error=8.728
# >epoch=243, lrate=0.300, error=8.716
# >epoch=244, lrate=0.300, error=8.704
# >epoch=245, lrate=0.300, error=8.692
# >epoch=246, lrate=0.300, error=8.680
# >epoch=247, lrate=0.300, error=8.668
# >epoch=248, lrate=0.300, error=8.657
# >epoch=249, lrate=0.300, error=8.645
# >epoch=250, lrate=0.300, error=8.633
# >epoch=251, lrate=0.300, error=8.622
# >epoch=252, lrate=0.300, error=8.610
# >epoch=253, lrate=0.300, error=8.599
# >epoch=254, lrate=0.300, error=8.587
# >epoch=255, lrate=0.300, error=8.576
# >epoch=256, lrate=0.300, error=8.565
# >epoch=257, lrate=0.300, error=8.554
# >epoch=258, lrate=0.300, error=8.542
# >epoch=259, lrate=0.300, error=8.531
# >epoch=260, lrate=0.300, error=8.520
# >epoch=261, lrate=0.300, error=8.509
# >epoch=262, lrate=0.300, error=8.498
# >epoch=263, lrate=0.300, error=8.487
# >epoch=264, lrate=0.300, error=8.476
# >epoch=265, lrate=0.300, error=8.466
# >epoch=266, lrate=0.300, error=8.455
# >epoch=267, lrate=0.300, error=8.444
# >epoch=268, lrate=0.300, error=8.434
# >epoch=269, lrate=0.300, error=8.423
# >epoch=270, lrate=0.300, error=8.412
# >epoch=271, lrate=0.300, error=8.402
# >epoch=272, lrate=0.300, error=8.391
# >epoch=273, lrate=0.300, error=8.381
# >epoch=274, lrate=0.300, error=8.371
# >epoch=275, lrate=0.300, error=8.360
# >epoch=276, lrate=0.300, error=8.350
# >epoch=277, lrate=0.300, error=8.340
# >epoch=278, lrate=0.300, error=8.330
# >epoch=279, lrate=0.300, error=8.319
# >epoch=280, lrate=0.300, error=8.309
# >epoch=281, lrate=0.300, error=8.299
# >epoch=282, lrate=0.300, error=8.289
# >epoch=283, lrate=0.300, error=8.279
# >epoch=284, lrate=0.300, error=8.269
# >epoch=285, lrate=0.300, error=8.259
# >epoch=286, lrate=0.300, error=8.249
# >epoch=287, lrate=0.300, error=8.239
# ...
# >epoch=73, lrate=0.300, error=14.740
# >epoch=74, lrate=0.300, error=14.635
# >epoch=75, lrate=0.300, error=14.530
# >epoch=76, lrate=0.300, error=14.427
# >epoch=77, lrate=0.300, error=14.325
# >epoch=78, lrate=0.300, error=14.224
# >epoch=79, lrate=0.300, error=14.125
# >epoch=80, lrate=0.300, error=14.026
# >epoch=81, lrate=0.300, error=13.929
# >epoch=82, lrate=0.300, error=13.833
# >epoch=83, lrate=0.300, error=13.738
# >epoch=84, lrate=0.300, error=13.645
# >epoch=85, lrate=0.300, error=13.552
# >epoch=86, lrate=0.300, error=13.461
# >epoch=87, lrate=0.300, error=13.371
# >epoch=88, lrate=0.300, error=13.283
# >epoch=89, lrate=0.300, error=13.195
# >epoch=90, lrate=0.300, error=13.109
# >epoch=91, lrate=0.300, error=13.024
# >epoch=92, lrate=0.300, error=12.940
# >epoch=93, lrate=0.300, error=12.857
# >epoch=94, lrate=0.300, error=12.776
# >epoch=95, lrate=0.300, error=12.696
# >epoch=96, lrate=0.300, error=12.617
# >epoch=97, lrate=0.300, error=12.539
# >epoch=98, lrate=0.300, error=12.462
# >epoch=99, lrate=0.300, error=12.387
# >epoch=100, lrate=0.300, error=12.312
# >epoch=101, lrate=0.300, error=12.239
# >epoch=102, lrate=0.300, error=12.167
# >epoch=103, lrate=0.300, error=12.096
# >epoch=104, lrate=0.300, error=12.026
# >epoch=105, lrate=0.300, error=11.957
# >epoch=106, lrate=0.300, error=11.889
# >epoch=107, lrate=0.300, error=11.823
# >epoch=108, lrate=0.300, error=11.757
# >epoch=109, lrate=0.300, error=11.693
# >epoch=110, lrate=0.300, error=11.629
# >epoch=111, lrate=0.300, error=11.567
# >epoch=112, lrate=0.300, error=11.505
# >epoch=113, lrate=0.300, error=11.444
# >epoch=114, lrate=0.300, error=11.385
# >epoch=115, lrate=0.300, error=11.326
# >epoch=116, lrate=0.300, error=11.268
# >epoch=117, lrate=0.300, error=11.211
# >epoch=118, lrate=0.300, error=11.155
# >epoch=119, lrate=0.300, error=11.100
# >epoch=120, lrate=0.300, error=11.046
# >epoch=121, lrate=0.300, error=10.992
# >epoch=122, lrate=0.300, error=10.939
# >epoch=123, lrate=0.300, error=10.887
# >epoch=124, lrate=0.300, error=10.836
# >epoch=125, lrate=0.300, error=10.786
# >epoch=126, lrate=0.300, error=10.736
# >epoch=127, lrate=0.300, error=10.687
# >epoch=128, lrate=0.300, error=10.639
# >epoch=129, lrate=0.300, error=10.592
# >epoch=130, lrate=0.300, error=10.545
# >epoch=131, lrate=0.300, error=10.499
# >epoch=132, lrate=0.300, error=10.453
# >epoch=133, lrate=0.300, error=10.408
# >epoch=134, lrate=0.300, error=10.364
# >epoch=135, lrate=0.300, error=10.320
# >epoch=136, lrate=0.300, error=10.277
# >epoch=137, lrate=0.300, error=10.235
# >epoch=138, lrate=0.300, error=10.193
# >epoch=139, lrate=0.300, error=10.152
# >epoch=140, lrate=0.300, error=10.111
# >epoch=141, lrate=0.300, error=10.070
# >epoch=142, lrate=0.300, error=10.031
# >epoch=143, lrate=0.300, error=9.992
# >epoch=144, lrate=0.300, error=9.953
# >epoch=145, lrate=0.300, error=9.915
# >epoch=146, lrate=0.300, error=9.877
# >epoch=147, lrate=0.300, error=9.840
# >epoch=148, lrate=0.300, error=9.803
# >epoch=149, lrate=0.300, error=9.766
# >epoch=150, lrate=0.300, error=9.731
# >epoch=151, lrate=0.300, error=9.695
# >epoch=152, lrate=0.300, error=9.660
# >epoch=153, lrate=0.300, error=9.625
# >epoch=154, lrate=0.300, error=9.591
# >epoch=155, lrate=0.300, error=9.557
# >epoch=156, lrate=0.300, error=9.524
# >epoch=157, lrate=0.300, error=9.491
# >epoch=158, lrate=0.300, error=9.458
# >epoch=159, lrate=0.300, error=9.426
# >epoch=160, lrate=0.300, error=9.394
# >epoch=161, lrate=0.300, error=9.362
# >epoch=162, lrate=0.300, error=9.331
# >epoch=163, lrate=0.300, error=9.300
# >epoch=164, lrate=0.300, error=9.270
# >epoch=165, lrate=0.300, error=9.239
# >epoch=166, lrate=0.300, error=9.209
# >epoch=167, lrate=0.300, error=9.180
# >epoch=168, lrate=0.300, error=9.151
# >epoch=169, lrate=0.300, error=9.121
# >epoch=170, lrate=0.300, error=9.093
# >epoch=171, lrate=0.300, error=9.064
# >epoch=172, lrate=0.300, error=9.036
# >epoch=173, lrate=0.300, error=9.008
# >epoch=174, lrate=0.300, error=8.981
# >epoch=175, lrate=0.300, error=8.953
# >epoch=176, lrate=0.300, error=8.926
# >epoch=177, lrate=0.300, error=8.899
# >epoch=178, lrate=0.300, error=8.873
# >epoch=179, lrate=0.300, error=8.847
# >epoch=180, lrate=0.300, error=8.820
# >epoch=181, lrate=0.300, error=8.795
# >epoch=182, lrate=0.300, error=8.769
# >epoch=183, lrate=0.300, error=8.744
# >epoch=184, lrate=0.300, error=8.718
# >epoch=185, lrate=0.300, error=8.693
# >epoch=186, lrate=0.300, error=8.669
# >epoch=187, lrate=0.300, error=8.644
# >epoch=188, lrate=0.300, error=8.620
# >epoch=189, lrate=0.300, error=8.596
# >epoch=190, lrate=0.300, error=8.572
# >epoch=191, lrate=0.300, error=8.548
# >epoch=192, lrate=0.300, error=8.524
# >epoch=193, lrate=0.300, error=8.501
# >epoch=194, lrate=0.300, error=8.478
# >epoch=195, lrate=0.300, error=8.455
# >epoch=196, lrate=0.300, error=8.432
# >epoch=197, lrate=0.300, error=8.409
# >epoch=198, lrate=0.300, error=8.387
# >epoch=199, lrate=0.300, error=8.364
# >epoch=200, lrate=0.300, error=8.342
# >epoch=201, lrate=0.300, error=8.320
# >epoch=202, lrate=0.300, error=8.298
# >epoch=203, lrate=0.300, error=8.276
# >epoch=204, lrate=0.300, error=8.255
# >epoch=205, lrate=0.300, error=8.233
# >epoch=206, lrate=0.300, error=8.212
# >epoch=207, lrate=0.300, error=8.191
# >epoch=208, lrate=0.300, error=8.170
# >epoch=209, lrate=0.300, error=8.149
# >epoch=210, lrate=0.300, error=8.128
# >epoch=211, lrate=0.300, error=8.108
# >epoch=212, lrate=0.300, error=8.087
# >epoch=213, lrate=0.300, error=8.067
# >epoch=214, lrate=0.300, error=8.046
# >epoch=215, lrate=0.300, error=8.026
# >epoch=216, lrate=0.300, error=8.006
# >epoch=217, lrate=0.300, error=7.986
# >epoch=218, lrate=0.300, error=7.967
# >epoch=219, lrate=0.300, error=7.947
# >epoch=220, lrate=0.300, error=7.927
# >epoch=221, lrate=0.300, error=7.908
# >epoch=222, lrate=0.300, error=7.889
# >epoch=223, lrate=0.300, error=7.869
# >epoch=224, lrate=0.300, error=7.850
# >epoch=225, lrate=0.300, error=7.831
# >epoch=226, lrate=0.300, error=7.812
# >epoch=227, lrate=0.300, error=7.793
# >epoch=228, lrate=0.300, error=7.775
# >epoch=229, lrate=0.300, error=7.756
# >epoch=230, lrate=0.300, error=7.737
# >epoch=231, lrate=0.300, error=7.719
# >epoch=232, lrate=0.300, error=7.700
# >epoch=233, lrate=0.300, error=7.682
# >epoch=234, lrate=0.300, error=7.664
# >epoch=235, lrate=0.300, error=7.646
# >epoch=236, lrate=0.300, error=7.628
# >epoch=237, lrate=0.300, error=7.610
# >epoch=238, lrate=0.300, error=7.592
# >epoch=239, lrate=0.300, error=7.574
# >epoch=240, lrate=0.300, error=7.557
# >epoch=241, lrate=0.300, error=7.539
# >epoch=242, lrate=0.300, error=7.522
# >epoch=243, lrate=0.300, error=7.504
# >epoch=244, lrate=0.300, error=7.487
# >epoch=245, lrate=0.300, error=7.469
# >epoch=246, lrate=0.300, error=7.452
# >epoch=247, lrate=0.300, error=7.435
# >epoch=248, lrate=0.300, error=7.418
# >epoch=249, lrate=0.300, error=7.401
# >epoch=250, lrate=0.300, error=7.384
# >epoch=251, lrate=0.300, error=7.367
# >epoch=252, lrate=0.300, error=7.351
# >epoch=253, lrate=0.300, error=7.334
# >epoch=254, lrate=0.300, error=7.317
# >epoch=255, lrate=0.300, error=7.301
# >epoch=256, lrate=0.300, error=7.284
# >epoch=257, lrate=0.300, error=7.268
# >epoch=258, lrate=0.300, error=7.252
# >epoch=259, lrate=0.300, error=7.235
# >epoch=260, lrate=0.300, error=7.219
# >epoch=261, lrate=0.300, error=7.203
# >epoch=262, lrate=0.300, error=7.187
# >epoch=263, lrate=0.300, error=7.171
# >epoch=264, lrate=0.300, error=7.155
# >epoch=265, lrate=0.300, error=7.139
# >epoch=266, lrate=0.300, error=7.124
# >epoch=267, lrate=0.300, error=7.108
# >epoch=268, lrate=0.300, error=7.092
# >epoch=269, lrate=0.300, error=7.077
# >epoch=270, lrate=0.300, error=7.061
# >epoch=271, lrate=0.300, error=7.046
# >epoch=272, lrate=0.300, error=7.030
# >epoch=273, lrate=0.300, error=7.015
# >epoch=274, lrate=0.300, error=7.000
# >epoch=275, lrate=0.300, error=6.984
# >epoch=276, lrate=0.300, error=6.969
# >epoch=277, lrate=0.300, error=6.954
# >epoch=278, lrate=0.300, error=6.939
# >epoch=279, lrate=0.300, error=6.924
# >epoch=280, lrate=0.300, error=6.909
# >epoch=281, lrate=0.300, error=6.894
# >epoch=282, lrate=0.300, error=6.879
# >epoch=283, lrate=0.300, error=6.865
# >epoch=284, lrate=0.300, error=6.850
# >epoch=285, lrate=0.300, error=6.835
# >epoch=286, lrate=0.300, error=6.821
# >epoch=287, lrate=0.300, error=6.806
# >epoch=288, lrate=0.300, error=6.792
# >epoch=289, lrate=0.300, error=6.777
# >epoch=290, lrate=0.300, error=6.763
# >epoch=291, lrate=0.300, error=6.749
# >epoch=292, lrate=0.300, error=6.734
# >epoch=293, lrate=0.300, error=6.720
# >epoch=294, lrate=0.300, error=6.706
# >epoch=295, lrate=0.300, error=6.692
# >epoch=296, lrate=0.300, error=6.678
# >epoch=297, lrate=0.300, error=6.664
# >epoch=298, lrate=0.300, error=6.650
# >epoch=299, lrate=0.300, error=6.636
# >epoch=300, lrate=0.300, error=6.622
# >epoch=301, lrate=0.300, error=6.608
# >epoch=302, lrate=0.300, error=6.594
# >epoch=303, lrate=0.300, error=6.581
# >epoch=304, lrate=0.300, error=6.567
# >epoch=305, lrate=0.300, error=6.553
# >epoch=306, lrate=0.300, error=6.540
# >epoch=307, lrate=0.300, error=6.526
# >epoch=308, lrate=0.300, error=6.513
# >epoch=309, lrate=0.300, error=6.499
# >epoch=310, lrate=0.300, error=6.486
# >epoch=311, lrate=0.300, error=6.472
# >epoch=312, lrate=0.300, error=6.459
# >epoch=313, lrate=0.300, error=6.446
# >epoch=314, lrate=0.300, error=6.432
# >epoch=315, lrate=0.300, error=6.419
# >epoch=316, lrate=0.300, error=6.406
# >epoch=317, lrate=0.300, error=6.393
# >epoch=318, lrate=0.300, error=6.380
# >epoch=319, lrate=0.300, error=6.366
# >epoch=320, lrate=0.300, error=6.353
# >epoch=321, lrate=0.300, error=6.340
# >epoch=322, lrate=0.300, error=6.327
# >epoch=323, lrate=0.300, error=6.314
# >epoch=324, lrate=0.300, error=6.301
# >epoch=325, lrate=0.300, error=6.288
# >epoch=326, lrate=0.300, error=6.275
# >epoch=327, lrate=0.300, error=6.263
# >epoch=328, lrate=0.300, error=6.250
# >epoch=329, lrate=0.300, error=6.237
# >epoch=330, lrate=0.300, error=6.224
# >epoch=331, lrate=0.300, error=6.211
# >epoch=332, lrate=0.300, error=6.199
# >epoch=333, lrate=0.300, error=6.186
# >epoch=334, lrate=0.300, error=6.173
# >epoch=335, lrate=0.300, error=6.161
# >epoch=336, lrate=0.300, error=6.148
# >epoch=337, lrate=0.300, error=6.135
# >epoch=338, lrate=0.300, error=6.123
# >epoch=339, lrate=0.300, error=6.110
# >epoch=340, lrate=0.300, error=6.098
# >epoch=341, lrate=0.300, error=6.085
# >epoch=342, lrate=0.300, error=6.073
# >epoch=343, lrate=0.300, error=6.060
# >epoch=344, lrate=0.300, error=6.048
# >epoch=345, lrate=0.300, error=6.035
# >epoch=346, lrate=0.300, error=6.023
# >epoch=347, lrate=0.300, error=6.011
# >epoch=348, lrate=0.300, error=5.998
# >epoch=349, lrate=0.300, error=5.986
# >epoch=350, lrate=0.300, error=5.974
# >epoch=351, lrate=0.300, error=5.961
# >epoch=352, lrate=0.300, error=5.949
# >epoch=353, lrate=0.300, error=5.937
# >epoch=354, lrate=0.300, error=5.924
# >epoch=355, lrate=0.300, error=5.912
# >epoch=356, lrate=0.300, error=5.900
# >epoch=357, lrate=0.300, error=5.888
# >epoch=358, lrate=0.300, error=5.875
# >epoch=359, lrate=0.300, error=5.863
# >epoch=360, lrate=0.300, error=5.851
# >epoch=361, lrate=0.300, error=5.839
# >epoch=362, lrate=0.300, error=5.827
# >epoch=363, lrate=0.300, error=5.815
# >epoch=364, lrate=0.300, error=5.803
# >epoch=365, lrate=0.300, error=5.790
# >epoch=366, lrate=0.300, error=5.778
# >epoch=367, lrate=0.300, error=5.766
# >epoch=368, lrate=0.300, error=5.754
# >epoch=369, lrate=0.300, error=5.742
# >epoch=370, lrate=0.300, error=5.730
# >epoch=371, lrate=0.300, error=5.718
# >epoch=372, lrate=0.300, error=5.706
# >epoch=373, lrate=0.300, error=5.694
# >epoch=374, lrate=0.300, error=5.682
# >epoch=375, lrate=0.300, error=5.670
# >epoch=376, lrate=0.300, error=5.658
# >epoch=377, lrate=0.300, error=5.646
# >epoch=378, lrate=0.300, error=5.634
# >epoch=379, lrate=0.300, error=5.622
# >epoch=380, lrate=0.300, error=5.610
# >epoch=381, lrate=0.300, error=5.598
# >epoch=382, lrate=0.300, error=5.587
# >epoch=383, lrate=0.300, error=5.575
# >epoch=384, lrate=0.300, error=5.563
# >epoch=385, lrate=0.300, error=5.551
# >epoch=386, lrate=0.300, error=5.539
# >epoch=387, lrate=0.300, error=5.527
# >epoch=388, lrate=0.300, error=5.515
# >epoch=389, lrate=0.300, error=5.504
# >epoch=390, lrate=0.300, error=5.492
# >epoch=391, lrate=0.300, error=5.480
# >epoch=392, lrate=0.300, error=5.468
# >epoch=393, lrate=0.300, error=5.456
# >epoch=394, lrate=0.300, error=5.445
# >epoch=395, lrate=0.300, error=5.433
# >epoch=396, lrate=0.300, error=5.421
# >epoch=397, lrate=0.300, error=5.409
# >epoch=398, lrate=0.300, error=5.398
# >epoch=399, lrate=0.300, error=5.386
# >epoch=400, lrate=0.300, error=5.374
# >epoch=401, lrate=0.300, error=5.362
# >epoch=402, lrate=0.300, error=5.351
# >epoch=403, lrate=0.300, error=5.339
# >epoch=404, lrate=0.300, error=5.327
# >epoch=405, lrate=0.300, error=5.316
# >epoch=406, lrate=0.300, error=5.304
# >epoch=407, lrate=0.300, error=5.292
# >epoch=408, lrate=0.300, error=5.281
# >epoch=409, lrate=0.300, error=5.269
# >epoch=410, lrate=0.300, error=5.258
# >epoch=411, lrate=0.300, error=5.246
# >epoch=412, lrate=0.300, error=5.234
# >epoch=413, lrate=0.300, error=5.223
# >epoch=414, lrate=0.300, error=5.211
# >epoch=415, lrate=0.300, error=5.200
# >epoch=416, lrate=0.300, error=5.188
# >epoch=417, lrate=0.300, error=5.176
# >epoch=418, lrate=0.300, error=5.165
# >epoch=419, lrate=0.300, error=5.153
# >epoch=420, lrate=0.300, error=5.142
# >epoch=421, lrate=0.300, error=5.130
# >epoch=422, lrate=0.300, error=5.119
# >epoch=423, lrate=0.300, error=5.107
# >epoch=424, lrate=0.300, error=5.096
# >epoch=425, lrate=0.300, error=5.084
# >epoch=426, lrate=0.300, error=5.073
# >epoch=427, lrate=0.300, error=5.061
# >epoch=428, lrate=0.300, error=5.050
# >epoch=429, lrate=0.300, error=5.038
# >epoch=430, lrate=0.300, error=5.027
# >epoch=431, lrate=0.300, error=5.015
# >epoch=432, lrate=0.300, error=5.004
# >epoch=433, lrate=0.300, error=4.992
# >epoch=434, lrate=0.300, error=4.981
# >epoch=435, lrate=0.300, error=4.970
# >epoch=436, lrate=0.300, error=4.958
# >epoch=437, lrate=0.300, error=4.947
# >epoch=438, lrate=0.300, error=4.935
# >epoch=439, lrate=0.300, error=4.924
# >epoch=440, lrate=0.300, error=4.913
# >epoch=441, lrate=0.300, error=4.901
# >epoch=442, lrate=0.300, error=4.890
# >epoch=443, lrate=0.300, error=4.879
# >epoch=444, lrate=0.300, error=4.867
# >epoch=445, lrate=0.300, error=4.856
# >epoch=446, lrate=0.300, error=4.845
# >epoch=447, lrate=0.300, error=4.833
# >epoch=448, lrate=0.300, error=4.822
# >epoch=449, lrate=0.300, error=4.811
# >epoch=450, lrate=0.300, error=4.799
# >epoch=451, lrate=0.300, error=4.788
# >epoch=452, lrate=0.300, error=4.777
# >epoch=453, lrate=0.300, error=4.765
# >epoch=454, lrate=0.300, error=4.754
# >epoch=455, lrate=0.300, error=4.743
# >epoch=456, lrate=0.300, error=4.732
# >epoch=457, lrate=0.300, error=4.720
# >epoch=458, lrate=0.300, error=4.709
# >epoch=459, lrate=0.300, error=4.698
# >epoch=460, lrate=0.300, error=4.687
# >epoch=461, lrate=0.300, error=4.676
# >epoch=462, lrate=0.300, error=4.664
# >epoch=463, lrate=0.300, error=4.653
# >epoch=464, lrate=0.300, error=4.642
# >epoch=465, lrate=0.300, error=4.631
# >epoch=466, lrate=0.300, error=4.620
# >epoch=467, lrate=0.300, error=4.608
# >epoch=468, lrate=0.300, error=4.597
# >epoch=469, lrate=0.300, error=4.586
# >epoch=470, lrate=0.300, error=4.575
# >epoch=471, lrate=0.300, error=4.564
# >epoch=472, lrate=0.300, error=4.553
# >epoch=473, lrate=0.300, error=4.542
# >epoch=474, lrate=0.300, error=4.531
# >epoch=475, lrate=0.300, error=4.519
# >epoch=476, lrate=0.300, error=4.508
# >epoch=477, lrate=0.300, error=4.497
# >epoch=478, lrate=0.300, error=4.486
# >epoch=479, lrate=0.300, error=4.475
# >epoch=480, lrate=0.300, error=4.464
# >epoch=481, lrate=0.300, error=4.453
# >epoch=482, lrate=0.300, error=4.442
# >epoch=483, lrate=0.300, error=4.431
# >epoch=484, lrate=0.300, error=4.420
# >epoch=485, lrate=0.300, error=4.409
# >epoch=486, lrate=0.300, error=4.398
# >epoch=487, lrate=0.300, error=4.387
# >epoch=488, lrate=0.300, error=4.376
# >epoch=489, lrate=0.300, error=4.365
# >epoch=490, lrate=0.300, error=4.354
# >epoch=491, lrate=0.300, error=4.343
# >epoch=492, lrate=0.300, error=4.332
# >epoch=493, lrate=0.300, error=4.321
# >epoch=494, lrate=0.300, error=4.310
# >epoch=495, lrate=0.300, error=4.299
# >epoch=496, lrate=0.300, error=4.288
# >epoch=497, lrate=0.300, error=4.277
# >epoch=498, lrate=0.300, error=4.266
# >epoch=499, lrate=0.300, error=4.255
# Scores ANN: [95.23809523809523, 92.85714285714286, 97.61904761904762, 92.85714285714286, 90.47619047619048]
# Mean Accuracy ANN: 93.810%

# %% [markdown]
# ### Comparing neural net with other methods on Wheat Seeds

# %%
# Comparing against other methods:
print("\nK-Nearest Neighbours:")
scores_knn = evaluate_algorithm(dataset, k_nearest_neighbours, n_folds, accuracy_metric, 3)
print('Scores KNN: %s' % scores_knn)
print('Mean Accuracy KNN: %.3f%%' % (sum(scores_knn)/float(len(scores_knn))))

print("\nNaive Bayes:")
scores_nb = evaluate_algorithm(dataset, naive_bayes, n_folds)
print('Scores Naive Bayes: %s' % scores_nb)
print('Mean Accuracy Naive Bayes: %.3f%%' % (sum(scores_nb)/float(len(scores_nb))))

print("\nClassification and Regression Trees:")
scores_cart = evaluate_algorithm(dataset, decision_tree, n_folds, accuracy_metric, 5, 3)
print('Scores CART: %s' % scores_cart)
print('Mean Accuracy Cart: %.3f%%' % (sum(scores_cart)/float(len(scores_cart))))
# Out:
# K-Nearest Neighbours:
# Scores KNN: [97.61904761904762, 85.71428571428571, 90.47619047619048, 95.23809523809523, 97.61904761904762]
# Mean Accuracy KNN: 93.333%
#
# Naive Bayes:
# Scores Naive Bayes: [83.33333333333334, 92.85714285714286, 95.23809523809523, 100.0, 80.95238095238095]
# Mean Accuracy Naive Bayes: 90.476%
#
# Classification and Regression Trees:
# Scores CART: [90.47619047619048, 100.0, 95.23809523809523, 90.47619047619048, 95.23809523809523]
# Mean Accuracy Cart: 94.286%
