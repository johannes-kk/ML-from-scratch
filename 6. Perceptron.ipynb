# %% [markdown]
# # 6. Perceptron

# %%
from random import seed, randrange

from functions import *

# %% [markdown]
# ### Define functions
# * Perceptron, or single neuron, using SGD

# %%
# Make a prediction with weights based on perceptron (single neuron)
def predict_perceptron(row, weights):
    activation = weights[0]
    # Loop over all input columns except last (i.e. actual output)
    for i in range(len(row)-1):
        # For each column, multiply input by coefficient and update activation
        activation += weights[i + 1] * row[i]
    # Neuron fires if activation function >= 0, does not fire if < 0
    return 1.0 if activation >= 0.0 else 0.0

# Estimate Perceptron weights using Stochastic Gradient Descent (SGD)
# Inputs: learning rate, number of epochs, (mini) batch size with default 1
# Outputs: Perceptron weights
def train_weights_perceptron(train, l_rate, n_epoch, b = 1):
    # Initialize all weights to 0.0, including intercept (bias) at w0
    weights = [0.0 for col in range(len(train[0]))]
    for epoch in range(n_epoch):
        # Overall epoch squared error
        sum_error = 0.0
        # Counters to track batch index and overall train set index
        i, j = 0, 0
        # Average SUM(h - y) * xi over weights i, to multiply batch by learning rate
        adjustments = [0.0 for col in range(len(train[0]))]

        for row in train:
            # Increment batch and train set indices
            i += 1
            j += 1
            # Calculate prediction and error against actual based on latest weights
            prediction = predict_perceptron(row, weights)
            error = row[-1] - prediction
            # Square and add to overall epoch error
            sum_error += error**2

            # Add to batch weight adjustments based on corresponding inputs (except bias)
            adjustments[0] += error
            for k in range(len(row)-1):
                # Begin with first weight, skipping intercept at k = 0
                # First column in row corresponds to second weight, since first is intercept
                adjustments[k + 1] += error * row[k]

            # Adjust all weights if row is last in batch or overall train set
            if i == b or j == len(train):
                #print('Adjustments made at row # ', str(j))
                for k in range(len(adjustments)):
                    weights[k] = weights[k] + l_rate * (1/i) * adjustments[k]
                    # i = b when at end of batch, but i < b if train set ends mid-match
                # Reset batch adjustments and batch index counter
                adjustments = [0.0 for col in range(len(train[0]))]
                i = 0

        print('>epoch=%d, lrate=%.3f, error=%.3f' % (epoch, l_rate, sum_error))
    # Return weighs after iterating through all epochs -- and rows within each
    return weights

# Perceptron Algorithm with Stochastic Gradient Descent
# Input: train and test sets, learning rate, number of epochs, and batch size
# Output: list of predictions to compare against test data actual outputs
def perceptron(train, test, l_rate, n_epoch, b_size = 1):
    predictions = list()
    # Get Perceptron weights using SGD and input parameters
    weights = train_weights_perceptron(train, l_rate, n_epoch, b_size)
    # Predict output for all test rows, using Perceptron model built on train set
    for row in test:
        # Predict output based on test set inputs and weights estimated using train set
        prediction = predict_perceptron(row, weights)
        predictions.append(prediction)
    # Return predicted outputs in test set using train set weight estimates
    return predictions

# %% [markdown]
# ### Testing perceptron on contrived dataset

# %%
print("\nTesting prediction method using contrived dataset:")
# Contrived dataset: x1, x2, y
dataset =   [[2.7810836,2.550537003,0],
            [1.465489372,2.362125076,0],
            [3.396561688,4.400293529,0],
            [1.38807019,1.850220317,0],
            [3.06407232,3.005305973,0],
            [7.627531214,2.759262235,1],
            [5.332441248,2.088626775,1],
            [6.922596716,1.77106367,1],
            [8.675418651,-0.242068655,1],
            [7.673756466,3.508563011,1]]
# Hardcoded test weights: intercept (bias), x1, x2
weights = [-0.1, 0.20653640140000007, -0.23418117710000003]
# I.e. activation = -0.1 + 0.206*x1 - 0.234*x2
# Iterate over dataset rows, making and printing prediction
for row in dataset:
    prediction = predict_perceptron(row, weights)
    print("Expected=%d, Predicted=%d" % (row[-1], prediction))

print("\nTesting Stochastic Gradient Descent using contrived dataset:")
l_rate = 0.1
n_epoch = 5
weights = train_weights_perceptron(dataset, l_rate, n_epoch)
print(weights)
# Out:
# Testing prediction method using contrived dataset:
# Expected=0, Predicted=0
# Expected=0, Predicted=0
# Expected=0, Predicted=0
# Expected=0, Predicted=0
# Expected=0, Predicted=0
# Expected=1, Predicted=1
# Expected=1, Predicted=1
# Expected=1, Predicted=1
# Expected=1, Predicted=1
# Expected=1, Predicted=1
#
# Testing Stochastic Gradient Descent using contrived dataset:
# >epoch=0, lrate=0.100, error=2.000
# >epoch=1, lrate=0.100, error=1.000
# >epoch=2, lrate=0.100, error=0.000
# >epoch=3, lrate=0.100, error=0.000
# >epoch=4, lrate=0.100, error=0.000
# [-0.1, 0.20653640140000007, -0.23418117710000003]

# %% [markdown]
# ### Testing perceptron on Sonar dataset

# %%
print("\n Training Perceptron model using SGD on Sonar dataset:")
# Using k-fold cross validation and dynamic algorithm evaluation method
seed(1)
# Load dataset and convert all columns from string to float (numeric type)
dataset = load_csv('data/sonar.all-data.csv')
for i in range(len(dataset[0])-1):
    str_column_to_float(dataset, i)
# Convert last column from float to int, since binary classification output
str_column_to_int(dataset, len(dataset[0])-1)
# Splits dataset into 3 folds; 3 iterations of training on 2 folds and testing on 1
# 208 rows across 3 folds = 69.3 ~ 69 records per fold
n_folds = 3
l_rate = 0.1
# For each fold, the weights are exposed to the full train set and adjusted 500 times
n_epoch = 500
# In each epoch, weights are adjusted (number of rows / batch size) times
# Batch Gradient Descent if b = 138 = train size (2 folds, i.e. batch = all rows)
# Mini-batch if b < 138
b_size = 10

# l_rate and n_epoch are passed to Perceptron algorithm as *args by evaluate_algorithm
scores = evaluate_algorithm(dataset, perceptron, 3, accuracy_metric, l_rate, n_epoch, b_size)
print('Scores: %s' % scores)
print('Mean Accuracy: %.3f%%' % (sum(scores)/float(len(scores))))
# Out:
#  Training Perceptron model using SGD on Sonar dataset:
# Loaded data file data/sonar.all-data.csv with 208 rows and 61 columns.
# >epoch=0, lrate=0.100, error=68.000
# >epoch=1, lrate=0.100, error=65.000
# >epoch=2, lrate=0.100, error=46.000
# >epoch=3, lrate=0.100, error=56.000
# >epoch=4, lrate=0.100, error=59.000
# >epoch=5, lrate=0.100, error=41.000
# >epoch=6, lrate=0.100, error=52.000
# >epoch=7, lrate=0.100, error=46.000
# >epoch=8, lrate=0.100, error=42.000
# >epoch=9, lrate=0.100, error=40.000
# >epoch=10, lrate=0.100, error=38.000
# >epoch=11, lrate=0.100, error=36.000
# >epoch=12, lrate=0.100, error=41.000
# >epoch=13, lrate=0.100, error=44.000
# >epoch=14, lrate=0.100, error=47.000
# >epoch=15, lrate=0.100, error=44.000
# >epoch=16, lrate=0.100, error=38.000
# >epoch=17, lrate=0.100, error=42.000
# >epoch=18, lrate=0.100, error=41.000
# >epoch=19, lrate=0.100, error=35.000
# >epoch=20, lrate=0.100, error=35.000
# >epoch=21, lrate=0.100, error=34.000
# >epoch=22, lrate=0.100, error=27.000
# >epoch=23, lrate=0.100, error=37.000
# >epoch=24, lrate=0.100, error=27.000
# >epoch=25, lrate=0.100, error=28.000
# >epoch=26, lrate=0.100, error=32.000
# >epoch=27, lrate=0.100, error=32.000
# >epoch=28, lrate=0.100, error=32.000
# >epoch=29, lrate=0.100, error=32.000
# >epoch=30, lrate=0.100, error=27.000
# >epoch=31, lrate=0.100, error=32.000
# >epoch=32, lrate=0.100, error=40.000
# >epoch=33, lrate=0.100, error=35.000
# >epoch=34, lrate=0.100, error=30.000
# >epoch=35, lrate=0.100, error=33.000
# >epoch=36, lrate=0.100, error=41.000
# >epoch=37, lrate=0.100, error=35.000
# >epoch=38, lrate=0.100, error=42.000
# >epoch=39, lrate=0.100, error=32.000
# >epoch=40, lrate=0.100, error=36.000
# >epoch=41, lrate=0.100, error=20.000
# >epoch=42, lrate=0.100, error=29.000
# >epoch=43, lrate=0.100, error=24.000
# >epoch=44, lrate=0.100, error=23.000
# >epoch=45, lrate=0.100, error=28.000
# >epoch=46, lrate=0.100, error=34.000
# >epoch=47, lrate=0.100, error=28.000
# >epoch=48, lrate=0.100, error=33.000
# >epoch=49, lrate=0.100, error=28.000
# >epoch=50, lrate=0.100, error=31.000
# >epoch=51, lrate=0.100, error=30.000
# >epoch=52, lrate=0.100, error=37.000
# >epoch=53, lrate=0.100, error=29.000
# >epoch=54, lrate=0.100, error=26.000
# >epoch=55, lrate=0.100, error=30.000
# >epoch=56, lrate=0.100, error=26.000
# >epoch=57, lrate=0.100, error=30.000
# >epoch=58, lrate=0.100, error=31.000
# >epoch=59, lrate=0.100, error=35.000
# >epoch=60, lrate=0.100, error=23.000
# >epoch=61, lrate=0.100, error=23.000
# >epoch=62, lrate=0.100, error=25.000
# >epoch=63, lrate=0.100, error=40.000
# >epoch=64, lrate=0.100, error=30.000
# >epoch=65, lrate=0.100, error=34.000
# >epoch=66, lrate=0.100, error=22.000
# >epoch=67, lrate=0.100, error=24.000
# >epoch=68, lrate=0.100, error=34.000
# >epoch=69, lrate=0.100, error=32.000
# >epoch=70, lrate=0.100, error=35.000
# >epoch=71, lrate=0.100, error=27.000
# >epoch=72, lrate=0.100, error=39.000
# >epoch=73, lrate=0.100, error=29.000
# >epoch=74, lrate=0.100, error=23.000
# >epoch=75, lrate=0.100, error=25.000
# >epoch=76, lrate=0.100, error=30.000
# >epoch=77, lrate=0.100, error=31.000
# >epoch=78, lrate=0.100, error=30.000
# >epoch=79, lrate=0.100, error=26.000
# >epoch=80, lrate=0.100, error=31.000
# >epoch=81, lrate=0.100, error=26.000
# >epoch=82, lrate=0.100, error=35.000
# >epoch=83, lrate=0.100, error=26.000
# >epoch=84, lrate=0.100, error=32.000
# >epoch=85, lrate=0.100, error=25.000
# >epoch=86, lrate=0.100, error=30.000
# >epoch=87, lrate=0.100, error=34.000
# >epoch=88, lrate=0.100, error=27.000
# >epoch=89, lrate=0.100, error=22.000
# >epoch=90, lrate=0.100, error=33.000
# >epoch=91, lrate=0.100, error=34.000
# >epoch=92, lrate=0.100, error=29.000
# >epoch=93, lrate=0.100, error=28.000
# >epoch=94, lrate=0.100, error=27.000
# >epoch=95, lrate=0.100, error=33.000
# >epoch=96, lrate=0.100, error=25.000
# >epoch=97, lrate=0.100, error=31.000
# >epoch=98, lrate=0.100, error=23.000
# >epoch=99, lrate=0.100, error=23.000
# >epoch=100, lrate=0.100, error=30.000
# >epoch=101, lrate=0.100, error=23.000
# >epoch=102, lrate=0.100, error=40.000
# >epoch=103, lrate=0.100, error=30.000
# >epoch=104, lrate=0.100, error=21.000
# >epoch=105, lrate=0.100, error=26.000
# >epoch=106, lrate=0.100, error=28.000
# >epoch=107, lrate=0.100, error=32.000
# >epoch=108, lrate=0.100, error=24.000
# >epoch=109, lrate=0.100, error=27.000
# >epoch=110, lrate=0.100, error=29.000
# >epoch=111, lrate=0.100, error=26.000
# >epoch=112, lrate=0.100, error=26.000
# >epoch=113, lrate=0.100, error=31.000
# >epoch=114, lrate=0.100, error=28.000
# >epoch=115, lrate=0.100, error=21.000
# >epoch=116, lrate=0.100, error=25.000
# >epoch=117, lrate=0.100, error=25.000
# >epoch=118, lrate=0.100, error=32.000
# >epoch=119, lrate=0.100, error=26.000
# >epoch=120, lrate=0.100, error=33.000
# >epoch=121, lrate=0.100, error=32.000
# >epoch=122, lrate=0.100, error=25.000
# >epoch=123, lrate=0.100, error=29.000
# >epoch=124, lrate=0.100, error=24.000
# >epoch=125, lrate=0.100, error=26.000
# >epoch=126, lrate=0.100, error=31.000
# >epoch=127, lrate=0.100, error=30.000
# >epoch=128, lrate=0.100, error=29.000
# >epoch=129, lrate=0.100, error=22.000
# >epoch=130, lrate=0.100, error=23.000
# >epoch=131, lrate=0.100, error=30.000
# >epoch=132, lrate=0.100, error=21.000
# >epoch=133, lrate=0.100, error=19.000
# >epoch=134, lrate=0.100, error=23.000
# >epoch=135, lrate=0.100, error=29.000
# >epoch=136, lrate=0.100, error=27.000
# >epoch=137, lrate=0.100, error=23.000
# >epoch=138, lrate=0.100, error=27.000
# >epoch=139, lrate=0.100, error=26.000
# >epoch=140, lrate=0.100, error=25.000
# >epoch=141, lrate=0.100, error=29.000
# >epoch=142, lrate=0.100, error=24.000
# >epoch=143, lrate=0.100, error=27.000
# >epoch=144, lrate=0.100, error=22.000
# >epoch=145, lrate=0.100, error=28.000
# >epoch=146, lrate=0.100, error=23.000
# >epoch=147, lrate=0.100, error=30.000
# >epoch=148, lrate=0.100, error=27.000
# >epoch=149, lrate=0.100, error=25.000
# >epoch=150, lrate=0.100, error=28.000
# >epoch=151, lrate=0.100, error=18.000
# >epoch=152, lrate=0.100, error=29.000
# >epoch=153, lrate=0.100, error=24.000
# >epoch=154, lrate=0.100, error=27.000
# >epoch=155, lrate=0.100, error=27.000
# >epoch=156, lrate=0.100, error=27.000
# >epoch=157, lrate=0.100, error=29.000
# >epoch=158, lrate=0.100, error=22.000
# >epoch=159, lrate=0.100, error=28.000
# >epoch=160, lrate=0.100, error=32.000
# >epoch=161, lrate=0.100, error=23.000
# >epoch=162, lrate=0.100, error=24.000
# >epoch=163, lrate=0.100, error=30.000
# >epoch=164, lrate=0.100, error=30.000
# >epoch=165, lrate=0.100, error=23.000
# >epoch=166, lrate=0.100, error=22.000
# >epoch=167, lrate=0.100, error=28.000
# >epoch=168, lrate=0.100, error=23.000
# >epoch=169, lrate=0.100, error=22.000
# >epoch=170, lrate=0.100, error=24.000
# >epoch=171, lrate=0.100, error=23.000
# >epoch=172, lrate=0.100, error=33.000
# >epoch=173, lrate=0.100, error=26.000
# >epoch=174, lrate=0.100, error=22.000
# >epoch=175, lrate=0.100, error=26.000
# >epoch=176, lrate=0.100, error=27.000
# >epoch=177, lrate=0.100, error=26.000
# >epoch=178, lrate=0.100, error=23.000
# >epoch=179, lrate=0.100, error=25.000
# >epoch=180, lrate=0.100, error=24.000
# >epoch=181, lrate=0.100, error=25.000
# >epoch=182, lrate=0.100, error=20.000
# >epoch=183, lrate=0.100, error=19.000
# >epoch=184, lrate=0.100, error=22.000
# >epoch=185, lrate=0.100, error=19.000
# >epoch=186, lrate=0.100, error=21.000
# >epoch=187, lrate=0.100, error=29.000
# >epoch=188, lrate=0.100, error=23.000
# >epoch=189, lrate=0.100, error=21.000
# >epoch=190, lrate=0.100, error=31.000
# >epoch=191, lrate=0.100, error=19.000
# >epoch=192, lrate=0.100, error=23.000
# >epoch=193, lrate=0.100, error=26.000
# >epoch=194, lrate=0.100, error=26.000
# >epoch=195, lrate=0.100, error=25.000
# >epoch=196, lrate=0.100, error=23.000
# >epoch=197, lrate=0.100, error=34.000
# >epoch=198, lrate=0.100, error=29.000
# >epoch=199, lrate=0.100, error=24.000
# >epoch=200, lrate=0.100, error=27.000
# >epoch=201, lrate=0.100, error=24.000
# >epoch=202, lrate=0.100, error=21.000
# >epoch=203, lrate=0.100, error=28.000
# >epoch=204, lrate=0.100, error=16.000
# >epoch=205, lrate=0.100, error=26.000
# >epoch=206, lrate=0.100, error=18.000
# >epoch=207, lrate=0.100, error=26.000
# >epoch=208, lrate=0.100, error=22.000
# >epoch=209, lrate=0.100, error=30.000
# >epoch=210, lrate=0.100, error=16.000
# >epoch=211, lrate=0.100, error=30.000
# >epoch=212, lrate=0.100, error=29.000
# >epoch=213, lrate=0.100, error=21.000
# >epoch=214, lrate=0.100, error=26.000
# >epoch=215, lrate=0.100, error=21.000
# >epoch=216, lrate=0.100, error=23.000
# >epoch=217, lrate=0.100, error=26.000
# >epoch=218, lrate=0.100, error=22.000
# >epoch=219, lrate=0.100, error=24.000
# >epoch=220, lrate=0.100, error=28.000
# >epoch=221, lrate=0.100, error=28.000
# >epoch=222, lrate=0.100, error=26.000
# >epoch=223, lrate=0.100, error=26.000
# >epoch=224, lrate=0.100, error=23.000
# >epoch=225, lrate=0.100, error=19.000
# >epoch=226, lrate=0.100, error=18.000
# >epoch=227, lrate=0.100, error=26.000
# >epoch=228, lrate=0.100, error=27.000
# >epoch=229, lrate=0.100, error=21.000
# >epoch=230, lrate=0.100, error=23.000
# >epoch=231, lrate=0.100, error=25.000
# >epoch=232, lrate=0.100, error=24.000
# >epoch=233, lrate=0.100, error=17.000
# >epoch=234, lrate=0.100, error=26.000
# >epoch=235, lrate=0.100, error=23.000
# >epoch=236, lrate=0.100, error=24.000
# >epoch=237, lrate=0.100, error=27.000
# >epoch=238, lrate=0.100, error=21.000
# >epoch=239, lrate=0.100, error=25.000
# >epoch=240, lrate=0.100, error=20.000
# >epoch=241, lrate=0.100, error=18.000
# >epoch=242, lrate=0.100, error=20.000
# >epoch=243, lrate=0.100, error=23.000
# >epoch=244, lrate=0.100, error=21.000
# >epoch=245, lrate=0.100, error=24.000
# >epoch=246, lrate=0.100, error=25.000
# >epoch=247, lrate=0.100, error=23.000
# >epoch=248, lrate=0.100, error=25.000
# >epoch=249, lrate=0.100, error=23.000
# >epoch=250, lrate=0.100, error=25.000
# >epoch=251, lrate=0.100, error=22.000
# >epoch=252, lrate=0.100, error=30.000
# >epoch=253, lrate=0.100, error=26.000
# >epoch=254, lrate=0.100, error=25.000
# >epoch=255, lrate=0.100, error=25.000
# >epoch=256, lrate=0.100, error=23.000
# >epoch=257, lrate=0.100, error=18.000
# >epoch=258, lrate=0.100, error=25.000
# >epoch=259, lrate=0.100, error=23.000
# >epoch=260, lrate=0.100, error=22.000
# >epoch=261, lrate=0.100, error=24.000
# >epoch=262, lrate=0.100, error=20.000
# >epoch=263, lrate=0.100, error=19.000
# >epoch=264, lrate=0.100, error=22.000
# >epoch=265, lrate=0.100, error=28.000
# >epoch=266, lrate=0.100, error=25.000
# >epoch=267, lrate=0.100, error=25.000
# >epoch=268, lrate=0.100, error=25.000
# >epoch=269, lrate=0.100, error=22.000
# >epoch=270, lrate=0.100, error=21.000
# >epoch=271, lrate=0.100, error=20.000
# >epoch=272, lrate=0.100, error=20.000
# >epoch=273, lrate=0.100, error=23.000
# >epoch=274, lrate=0.100, error=26.000
# >epoch=275, lrate=0.100, error=26.000
# >epoch=276, lrate=0.100, error=26.000
# >epoch=277, lrate=0.100, error=19.000
# >epoch=278, lrate=0.100, error=29.000
# >epoch=279, lrate=0.100, error=29.000
# >epoch=280, lrate=0.100, error=26.000
# >epoch=281, lrate=0.100, error=21.000
# >epoch=282, lrate=0.100, error=22.000
# >epoch=283, lrate=0.100, error=17.000
# >epoch=284, lrate=0.100, error=25.000
# >epoch=285, lrate=0.100, error=27.000
# >epoch=286, lrate=0.100, error=27.000
# >epoch=287, lrate=0.100, error=23.000
# >epoch=288, lrate=0.100, error=21.000
# >epoch=289, lrate=0.100, error=21.000
# >epoch=290, lrate=0.100, error=23.000
# >epoch=291, lrate=0.100, error=23.000
# >epoch=292, lrate=0.100, error=21.000
# >epoch=293, lrate=0.100, error=22.000
# >epoch=294, lrate=0.100, error=20.000
# >epoch=295, lrate=0.100, error=18.000
# >epoch=296, lrate=0.100, error=29.000
# >epoch=297, lrate=0.100, error=24.000
# >epoch=298, lrate=0.100, error=25.000
# >epoch=299, lrate=0.100, error=24.000
# >epoch=300, lrate=0.100, error=16.000
# >epoch=301, lrate=0.100, error=24.000
# >epoch=302, lrate=0.100, error=22.000
# >epoch=303, lrate=0.100, error=24.000
# >epoch=304, lrate=0.100, error=24.000
# >epoch=305, lrate=0.100, error=24.000
# >epoch=306, lrate=0.100, error=23.000
# >epoch=307, lrate=0.100, error=19.000
# >epoch=308, lrate=0.100, error=23.000
# >epoch=309, lrate=0.100, error=26.000
# >epoch=310, lrate=0.100, error=23.000
# >epoch=311, lrate=0.100, error=25.000
# >epoch=312, lrate=0.100, error=20.000
# >epoch=313, lrate=0.100, error=24.000
# >epoch=314, lrate=0.100, error=28.000
# >epoch=315, lrate=0.100, error=19.000
# >epoch=316, lrate=0.100, error=24.000
# >epoch=317, lrate=0.100, error=18.000
# >epoch=318, lrate=0.100, error=17.000
# >epoch=319, lrate=0.100, error=26.000
# >epoch=320, lrate=0.100, error=25.000
# >epoch=321, lrate=0.100, error=26.000
# >epoch=322, lrate=0.100, error=24.000
# >epoch=323, lrate=0.100, error=21.000
# >epoch=324, lrate=0.100, error=29.000
# >epoch=325, lrate=0.100, error=23.000
# >epoch=326, lrate=0.100, error=23.000
# >epoch=327, lrate=0.100, error=26.000
# >epoch=328, lrate=0.100, error=25.000
# >epoch=329, lrate=0.100, error=26.000
# >epoch=330, lrate=0.100, error=30.000
# >epoch=331, lrate=0.100, error=19.000
# >epoch=332, lrate=0.100, error=24.000
# >epoch=333, lrate=0.100, error=25.000
# >epoch=334, lrate=0.100, error=22.000
# >epoch=335, lrate=0.100, error=24.000
# >epoch=336, lrate=0.100, error=21.000
# >epoch=337, lrate=0.100, error=28.000
# >epoch=338, lrate=0.100, error=27.000
# >epoch=339, lrate=0.100, error=17.000
# >epoch=340, lrate=0.100, error=24.000
# >epoch=341, lrate=0.100, error=23.000
# >epoch=342, lrate=0.100, error=23.000
# >epoch=343, lrate=0.100, error=24.000
# >epoch=344, lrate=0.100, error=24.000
# >epoch=345, lrate=0.100, error=25.000
# >epoch=346, lrate=0.100, error=16.000
# >epoch=347, lrate=0.100, error=20.000
# >epoch=348, lrate=0.100, error=25.000
# >epoch=349, lrate=0.100, error=20.000
# >epoch=350, lrate=0.100, error=22.000
# >epoch=351, lrate=0.100, error=16.000
# >epoch=352, lrate=0.100, error=21.000
# >epoch=353, lrate=0.100, error=21.000
# >epoch=354, lrate=0.100, error=22.000
# >epoch=355, lrate=0.100, error=18.000
# >epoch=356, lrate=0.100, error=21.000
# >epoch=357, lrate=0.100, error=24.000
# >epoch=358, lrate=0.100, error=24.000
# >epoch=359, lrate=0.100, error=23.000
# >epoch=360, lrate=0.100, error=20.000
# >epoch=361, lrate=0.100, error=15.000
# >epoch=362, lrate=0.100, error=21.000
# >epoch=363, lrate=0.100, error=18.000
# >epoch=364, lrate=0.100, error=30.000
# >epoch=365, lrate=0.100, error=24.000
# >epoch=366, lrate=0.100, error=28.000
# >epoch=367, lrate=0.100, error=24.000
# >epoch=368, lrate=0.100, error=20.000
# >epoch=369, lrate=0.100, error=15.000
# >epoch=370, lrate=0.100, error=28.000
# >epoch=371, lrate=0.100, error=17.000
# >epoch=372, lrate=0.100, error=24.000
# >epoch=373, lrate=0.100, error=21.000
# >epoch=374, lrate=0.100, error=23.000
# >epoch=375, lrate=0.100, error=20.000
# >epoch=376, lrate=0.100, error=22.000
# >epoch=377, lrate=0.100, error=21.000
# >epoch=378, lrate=0.100, error=18.000
# >epoch=379, lrate=0.100, error=19.000
# >epoch=380, lrate=0.100, error=29.000
# >epoch=381, lrate=0.100, error=14.000
# >epoch=382, lrate=0.100, error=27.000
# >epoch=383, lrate=0.100, error=14.000
# >epoch=384, lrate=0.100, error=18.000
# >epoch=385, lrate=0.100, error=28.000
# >epoch=386, lrate=0.100, error=23.000
# >epoch=387, lrate=0.100, error=19.000
# >epoch=388, lrate=0.100, error=20.000
# >epoch=389, lrate=0.100, error=23.000
# >epoch=390, lrate=0.100, error=22.000
# >epoch=391, lrate=0.100, error=16.000
# >epoch=392, lrate=0.100, error=18.000
# >epoch=393, lrate=0.100, error=18.000
# >epoch=394, lrate=0.100, error=25.000
# >epoch=395, lrate=0.100, error=18.000
# >epoch=396, lrate=0.100, error=25.000
# >epoch=397, lrate=0.100, error=22.000
# >epoch=398, lrate=0.100, error=16.000
# >epoch=399, lrate=0.100, error=20.000
# >epoch=400, lrate=0.100, error=21.000
# >epoch=401, lrate=0.100, error=22.000
# >epoch=402, lrate=0.100, error=19.000
# >epoch=403, lrate=0.100, error=19.000
# >epoch=404, lrate=0.100, error=24.000
# >epoch=405, lrate=0.100, error=22.000
# >epoch=406, lrate=0.100, error=25.000
# >epoch=407, lrate=0.100, error=22.000
# >epoch=408, lrate=0.100, error=24.000
# >epoch=409, lrate=0.100, error=18.000
# >epoch=410, lrate=0.100, error=18.000
# >epoch=411, lrate=0.100, error=21.000
# >epoch=412, lrate=0.100, error=18.000
# >epoch=413, lrate=0.100, error=15.000
# >epoch=414, lrate=0.100, error=18.000
# >epoch=415, lrate=0.100, error=25.000
# >epoch=416, lrate=0.100, error=29.000
# >epoch=417, lrate=0.100, error=28.000
# >epoch=418, lrate=0.100, error=16.000
# >epoch=419, lrate=0.100, error=23.000
# >epoch=420, lrate=0.100, error=28.000
# >epoch=421, lrate=0.100, error=14.000
# >epoch=422, lrate=0.100, error=22.000
# >epoch=423, lrate=0.100, error=24.000
# >epoch=424, lrate=0.100, error=27.000
# >epoch=425, lrate=0.100, error=17.000
# >epoch=426, lrate=0.100, error=17.000
# >epoch=427, lrate=0.100, error=16.000
# >epoch=428, lrate=0.100, error=25.000
# >epoch=429, lrate=0.100, error=24.000
# >epoch=430, lrate=0.100, error=26.000
# >epoch=431, lrate=0.100, error=12.000
# >epoch=432, lrate=0.100, error=18.000
# >epoch=433, lrate=0.100, error=21.000
# >epoch=434, lrate=0.100, error=22.000
# >epoch=435, lrate=0.100, error=21.000
# >epoch=436, lrate=0.100, error=17.000
# >epoch=437, lrate=0.100, error=23.000
# >epoch=438, lrate=0.100, error=18.000
# >epoch=439, lrate=0.100, error=20.000
# >epoch=440, lrate=0.100, error=14.000
# >epoch=441, lrate=0.100, error=16.000
# >epoch=442, lrate=0.100, error=23.000
# >epoch=443, lrate=0.100, error=10.000
# >epoch=444, lrate=0.100, error=29.000
# >epoch=445, lrate=0.100, error=19.000
# >epoch=446, lrate=0.100, error=23.000
# >epoch=447, lrate=0.100, error=21.000
# >epoch=448, lrate=0.100, error=30.000
# >epoch=449, lrate=0.100, error=23.000
# >epoch=450, lrate=0.100, error=22.000
# >epoch=451, lrate=0.100, error=17.000
# >epoch=452, lrate=0.100, error=25.000
# >epoch=453, lrate=0.100, error=20.000
# >epoch=454, lrate=0.100, error=21.000
# >epoch=455, lrate=0.100, error=24.000
# >epoch=456, lrate=0.100, error=15.000
# >epoch=457, lrate=0.100, error=18.000
# >epoch=458, lrate=0.100, error=28.000
# >epoch=459, lrate=0.100, error=20.000
# >epoch=460, lrate=0.100, error=18.000
# >epoch=461, lrate=0.100, error=25.000
# >epoch=462, lrate=0.100, error=21.000
# >epoch=463, lrate=0.100, error=16.000
# >epoch=464, lrate=0.100, error=21.000
# >epoch=465, lrate=0.100, error=22.000
# >epoch=466, lrate=0.100, error=22.000
# >epoch=467, lrate=0.100, error=21.000
# >epoch=468, lrate=0.100, error=29.000
# >epoch=469, lrate=0.100, error=18.000
# >epoch=470, lrate=0.100, error=21.000
# >epoch=471, lrate=0.100, error=18.000
# >epoch=472, lrate=0.100, error=21.000
# >epoch=473, lrate=0.100, error=22.000
# >epoch=474, lrate=0.100, error=19.000
# >epoch=475, lrate=0.100, error=21.000
# >epoch=476, lrate=0.100, error=22.000
# >epoch=477, lrate=0.100, error=17.000
# >epoch=478, lrate=0.100, error=19.000
# >epoch=479, lrate=0.100, error=19.000
# >epoch=480, lrate=0.100, error=15.000
# >epoch=481, lrate=0.100, error=23.000
# >epoch=482, lrate=0.100, error=24.000
# >epoch=483, lrate=0.100, error=21.000
# >epoch=484, lrate=0.100, error=19.000
# >epoch=485, lrate=0.100, error=23.000
# >epoch=486, lrate=0.100, error=17.000
# >epoch=487, lrate=0.100, error=22.000
# >epoch=488, lrate=0.100, error=21.000
# >epoch=489, lrate=0.100, error=25.000
# >epoch=490, lrate=0.100, error=24.000
# >epoch=491, lrate=0.100, error=26.000
# >epoch=492, lrate=0.100, error=15.000
# >epoch=493, lrate=0.100, error=18.000
# >epoch=494, lrate=0.100, error=21.000
# >epoch=495, lrate=0.100, error=18.000
# >epoch=496, lrate=0.100, error=16.000
# >epoch=497, lrate=0.100, error=20.000
# >epoch=498, lrate=0.100, error=25.000
# >epoch=499, lrate=0.100, error=27.000
# >epoch=0, lrate=0.100, error=63.000
# >epoch=1, lrate=0.100, error=63.000
# >epoch=2, lrate=0.100, error=49.000
# >epoch=3, lrate=0.100, error=37.000
# >epoch=4, lrate=0.100, error=48.000
# >epoch=5, lrate=0.100, error=61.000
# >epoch=6, lrate=0.100, error=47.000
# >epoch=7, lrate=0.100, error=32.000
# >epoch=8, lrate=0.100, error=49.000
# >epoch=9, lrate=0.100, error=41.000
# >epoch=10, lrate=0.100, error=42.000
# >epoch=11, lrate=0.100, error=35.000
# >epoch=12, lrate=0.100, error=41.000
# >epoch=13, lrate=0.100, error=35.000
# >epoch=14, lrate=0.100, error=48.000
# >epoch=15, lrate=0.100, error=35.000
# >epoch=16, lrate=0.100, error=43.000
# >epoch=17, lrate=0.100, error=45.000
# >epoch=18, lrate=0.100, error=37.000
# >epoch=19, lrate=0.100, error=43.000
# >epoch=20, lrate=0.100, error=45.000
# >epoch=21, lrate=0.100, error=39.000
# >epoch=22, lrate=0.100, error=34.000
# >epoch=23, lrate=0.100, error=39.000
# >epoch=24, lrate=0.100, error=29.000
# >epoch=25, lrate=0.100, error=31.000
# >epoch=26, lrate=0.100, error=33.000
# >epoch=27, lrate=0.100, error=29.000
# >epoch=28, lrate=0.100, error=34.000
# >epoch=29, lrate=0.100, error=32.000
# >epoch=30, lrate=0.100, error=29.000
# >epoch=31, lrate=0.100, error=29.000
# >epoch=32, lrate=0.100, error=20.000
# >epoch=33, lrate=0.100, error=31.000
# >epoch=34, lrate=0.100, error=18.000
# >epoch=35, lrate=0.100, error=24.000
# >epoch=36, lrate=0.100, error=31.000
# >epoch=37, lrate=0.100, error=35.000
# >epoch=38, lrate=0.100, error=37.000
# >epoch=39, lrate=0.100, error=37.000
# >epoch=40, lrate=0.100, error=28.000
# >epoch=41, lrate=0.100, error=30.000
# >epoch=42, lrate=0.100, error=34.000
# >epoch=43, lrate=0.100, error=29.000
# >epoch=44, lrate=0.100, error=27.000
# >epoch=45, lrate=0.100, error=41.000
# >epoch=46, lrate=0.100, error=20.000
# >epoch=47, lrate=0.100, error=25.000
# >epoch=48, lrate=0.100, error=30.000
# >epoch=49, lrate=0.100, error=33.000
# >epoch=50, lrate=0.100, error=19.000
# >epoch=51, lrate=0.100, error=25.000
# >epoch=52, lrate=0.100, error=24.000
# >epoch=53, lrate=0.100, error=23.000
# >epoch=54, lrate=0.100, error=21.000
# >epoch=55, lrate=0.100, error=39.000
# >epoch=56, lrate=0.100, error=30.000
# >epoch=57, lrate=0.100, error=28.000
# >epoch=58, lrate=0.100, error=22.000
# >epoch=59, lrate=0.100, error=21.000
# >epoch=60, lrate=0.100, error=29.000
# >epoch=61, lrate=0.100, error=26.000
# >epoch=62, lrate=0.100, error=36.000
# >epoch=63, lrate=0.100, error=18.000
# >epoch=64, lrate=0.100, error=17.000
# >epoch=65, lrate=0.100, error=43.000
# >epoch=66, lrate=0.100, error=18.000
# >epoch=67, lrate=0.100, error=20.000
# >epoch=68, lrate=0.100, error=20.000
# >epoch=69, lrate=0.100, error=29.000
# >epoch=70, lrate=0.100, error=30.000
# >epoch=71, lrate=0.100, error=30.000
# >epoch=72, lrate=0.100, error=30.000
# >epoch=73, lrate=0.100, error=22.000
# >epoch=74, lrate=0.100, error=26.000
# >epoch=75, lrate=0.100, error=20.000
# >epoch=76, lrate=0.100, error=30.000
# >epoch=77, lrate=0.100, error=25.000
# >epoch=78, lrate=0.100, error=26.000
# >epoch=79, lrate=0.100, error=27.000
# >epoch=80, lrate=0.100, error=18.000
# >epoch=81, lrate=0.100, error=25.000
# >epoch=82, lrate=0.100, error=27.000
# >epoch=83, lrate=0.100, error=24.000
# >epoch=84, lrate=0.100, error=17.000
# >epoch=85, lrate=0.100, error=26.000
# >epoch=86, lrate=0.100, error=29.000
# >epoch=87, lrate=0.100, error=20.000
# >epoch=88, lrate=0.100, error=18.000
# >epoch=89, lrate=0.100, error=30.000
# >epoch=90, lrate=0.100, error=24.000
# >epoch=91, lrate=0.100, error=28.000
# >epoch=92, lrate=0.100, error=24.000
# >epoch=93, lrate=0.100, error=16.000
# >epoch=94, lrate=0.100, error=15.000
# >epoch=95, lrate=0.100, error=24.000
# >epoch=96, lrate=0.100, error=28.000
# >epoch=97, lrate=0.100, error=29.000
# >epoch=98, lrate=0.100, error=29.000
# >epoch=99, lrate=0.100, error=27.000
# >epoch=100, lrate=0.100, error=21.000
# >epoch=101, lrate=0.100, error=20.000
# >epoch=102, lrate=0.100, error=29.000
# >epoch=103, lrate=0.100, error=22.000
# >epoch=104, lrate=0.100, error=17.000
# >epoch=105, lrate=0.100, error=28.000
# >epoch=106, lrate=0.100, error=15.000
# >epoch=107, lrate=0.100, error=18.000
# >epoch=108, lrate=0.100, error=31.000
# >epoch=109, lrate=0.100, error=19.000
# >epoch=110, lrate=0.100, error=20.000
# >epoch=111, lrate=0.100, error=35.000
# >epoch=112, lrate=0.100, error=21.000
# >epoch=113, lrate=0.100, error=18.000
# >epoch=114, lrate=0.100, error=29.000
# >epoch=115, lrate=0.100, error=26.000
# >epoch=116, lrate=0.100, error=18.000
# >epoch=117, lrate=0.100, error=27.000
# >epoch=118, lrate=0.100, error=23.000
# >epoch=119, lrate=0.100, error=27.000
# >epoch=120, lrate=0.100, error=20.000
# >epoch=121, lrate=0.100, error=22.000
# >epoch=122, lrate=0.100, error=26.000
# >epoch=123, lrate=0.100, error=29.000
# >epoch=124, lrate=0.100, error=18.000
# >epoch=125, lrate=0.100, error=20.000
# >epoch=126, lrate=0.100, error=27.000
# >epoch=127, lrate=0.100, error=35.000
# >epoch=128, lrate=0.100, error=19.000
# >epoch=129, lrate=0.100, error=18.000
# >epoch=130, lrate=0.100, error=19.000
# >epoch=131, lrate=0.100, error=28.000
# >epoch=132, lrate=0.100, error=18.000
# >epoch=133, lrate=0.100, error=24.000
# >epoch=134, lrate=0.100, error=26.000
# >epoch=135, lrate=0.100, error=17.000
# >epoch=136, lrate=0.100, error=23.000
# >epoch=137, lrate=0.100, error=23.000
# >epoch=138, lrate=0.100, error=18.000
# >epoch=139, lrate=0.100, error=34.000
# >epoch=140, lrate=0.100, error=21.000
# >epoch=141, lrate=0.100, error=27.000
# >epoch=142, lrate=0.100, error=33.000
# >epoch=143, lrate=0.100, error=21.000
# >epoch=144, lrate=0.100, error=15.000
# >epoch=145, lrate=0.100, error=22.000
# >epoch=146, lrate=0.100, error=19.000
# >epoch=147, lrate=0.100, error=27.000
# >epoch=148, lrate=0.100, error=18.000
# >epoch=149, lrate=0.100, error=27.000
# >epoch=150, lrate=0.100, error=26.000
# >epoch=151, lrate=0.100, error=32.000
# >epoch=152, lrate=0.100, error=18.000
# >epoch=153, lrate=0.100, error=33.000
# >epoch=154, lrate=0.100, error=19.000
# >epoch=155, lrate=0.100, error=28.000
# >epoch=156, lrate=0.100, error=26.000
# >epoch=157, lrate=0.100, error=34.000
# >epoch=158, lrate=0.100, error=19.000
# >epoch=159, lrate=0.100, error=18.000
# >epoch=160, lrate=0.100, error=28.000
# >epoch=161, lrate=0.100, error=21.000
# >epoch=162, lrate=0.100, error=18.000
# >epoch=163, lrate=0.100, error=21.000
# >epoch=164, lrate=0.100, error=25.000
# >epoch=165, lrate=0.100, error=17.000
# >epoch=166, lrate=0.100, error=25.000
# >epoch=167, lrate=0.100, error=18.000
# >epoch=168, lrate=0.100, error=30.000
# >epoch=169, lrate=0.100, error=19.000
# >epoch=170, lrate=0.100, error=22.000
# >epoch=171, lrate=0.100, error=28.000
# >epoch=172, lrate=0.100, error=32.000
# >epoch=173, lrate=0.100, error=17.000
# >epoch=174, lrate=0.100, error=26.000
# >epoch=175, lrate=0.100, error=21.000
# >epoch=176, lrate=0.100, error=22.000
# >epoch=177, lrate=0.100, error=18.000
# >epoch=178, lrate=0.100, error=21.000
# >epoch=179, lrate=0.100, error=33.000
# >epoch=180, lrate=0.100, error=21.000
# >epoch=181, lrate=0.100, error=18.000
# >epoch=182, lrate=0.100, error=29.000
# >epoch=183, lrate=0.100, error=25.000
# >epoch=184, lrate=0.100, error=16.000
# >epoch=185, lrate=0.100, error=22.000
# >epoch=186, lrate=0.100, error=26.000
# >epoch=187, lrate=0.100, error=29.000
# >epoch=188, lrate=0.100, error=15.000
# >epoch=189, lrate=0.100, error=20.000
# >epoch=190, lrate=0.100, error=35.000
# >epoch=191, lrate=0.100, error=21.000
# >epoch=192, lrate=0.100, error=17.000
# >epoch=193, lrate=0.100, error=21.000
# >epoch=194, lrate=0.100, error=24.000
# >epoch=195, lrate=0.100, error=21.000
# >epoch=196, lrate=0.100, error=18.000
# >epoch=197, lrate=0.100, error=18.000
# >epoch=198, lrate=0.100, error=28.000
# >epoch=199, lrate=0.100, error=20.000
# >epoch=200, lrate=0.100, error=17.000
# >epoch=201, lrate=0.100, error=18.000
# >epoch=202, lrate=0.100, error=12.000
# >epoch=203, lrate=0.100, error=29.000
# >epoch=204, lrate=0.100, error=25.000
# >epoch=205, lrate=0.100, error=18.000
# >epoch=206, lrate=0.100, error=23.000
# >epoch=207, lrate=0.100, error=21.000
# >epoch=208, lrate=0.100, error=28.000
# >epoch=209, lrate=0.100, error=19.000
# >epoch=210, lrate=0.100, error=24.000
# >epoch=211, lrate=0.100, error=29.000
# >epoch=212, lrate=0.100, error=23.000
# >epoch=213, lrate=0.100, error=22.000
# >epoch=214, lrate=0.100, error=19.000
# >epoch=215, lrate=0.100, error=25.000
# >epoch=216, lrate=0.100, error=24.000
# >epoch=217, lrate=0.100, error=18.000
# >epoch=218, lrate=0.100, error=17.000
# >epoch=219, lrate=0.100, error=29.000
# >epoch=220, lrate=0.100, error=22.000
# >epoch=221, lrate=0.100, error=24.000
# >epoch=222, lrate=0.100, error=25.000
# >epoch=223, lrate=0.100, error=16.000
# >epoch=224, lrate=0.100, error=25.000
# >epoch=225, lrate=0.100, error=26.000
# >epoch=226, lrate=0.100, error=24.000
# >epoch=227, lrate=0.100, error=22.000
# >epoch=228, lrate=0.100, error=19.000
# >epoch=229, lrate=0.100, error=16.000
# >epoch=230, lrate=0.100, error=27.000
# >epoch=231, lrate=0.100, error=18.000
# >epoch=232, lrate=0.100, error=25.000
# >epoch=233, lrate=0.100, error=19.000
# >epoch=234, lrate=0.100, error=19.000
# >epoch=235, lrate=0.100, error=19.000
# >epoch=236, lrate=0.100, error=26.000
# >epoch=237, lrate=0.100, error=30.000
# >epoch=238, lrate=0.100, error=19.000
# >epoch=239, lrate=0.100, error=19.000
# >epoch=240, lrate=0.100, error=25.000
# >epoch=241, lrate=0.100, error=27.000
# >epoch=242, lrate=0.100, error=24.000
# >epoch=243, lrate=0.100, error=17.000
# >epoch=244, lrate=0.100, error=32.000
# >epoch=245, lrate=0.100, error=25.000
# >epoch=246, lrate=0.100, error=23.000
# >epoch=247, lrate=0.100, error=28.000
# >epoch=248, lrate=0.100, error=19.000
# >epoch=249, lrate=0.100, error=26.000
# >epoch=250, lrate=0.100, error=25.000
# >epoch=251, lrate=0.100, error=17.000
# >epoch=252, lrate=0.100, error=22.000
# >epoch=253, lrate=0.100, error=31.000
# >epoch=254, lrate=0.100, error=21.000
# >epoch=255, lrate=0.100, error=14.000
# >epoch=256, lrate=0.100, error=14.000
# >epoch=257, lrate=0.100, error=16.000
# >epoch=258, lrate=0.100, error=18.000
# >epoch=259, lrate=0.100, error=18.000
# >epoch=260, lrate=0.100, error=31.000
# >epoch=261, lrate=0.100, error=18.000
# >epoch=262, lrate=0.100, error=25.000
# >epoch=263, lrate=0.100, error=21.000
# >epoch=264, lrate=0.100, error=18.000
# >epoch=265, lrate=0.100, error=17.000
# >epoch=266, lrate=0.100, error=35.000
# >epoch=267, lrate=0.100, error=23.000
# >epoch=268, lrate=0.100, error=23.000
# >epoch=269, lrate=0.100, error=24.000
# >epoch=270, lrate=0.100, error=17.000
# >epoch=271, lrate=0.100, error=34.000
# >epoch=272, lrate=0.100, error=17.000
# >epoch=273, lrate=0.100, error=19.000
# >epoch=274, lrate=0.100, error=15.000
# >epoch=275, lrate=0.100, error=19.000
# >epoch=276, lrate=0.100, error=25.000
# >epoch=277, lrate=0.100, error=24.000
# >epoch=278, lrate=0.100, error=27.000
# >epoch=279, lrate=0.100, error=15.000
# >epoch=280, lrate=0.100, error=30.000
# >epoch=281, lrate=0.100, error=15.000
# >epoch=282, lrate=0.100, error=17.000
# >epoch=283, lrate=0.100, error=16.000
# >epoch=284, lrate=0.100, error=26.000
# >epoch=285, lrate=0.100, error=27.000
# >epoch=286, lrate=0.100, error=13.000
# >epoch=287, lrate=0.100, error=19.000
# >epoch=288, lrate=0.100, error=18.000
# >epoch=289, lrate=0.100, error=27.000
# >epoch=290, lrate=0.100, error=23.000
# >epoch=291, lrate=0.100, error=23.000
# >epoch=292, lrate=0.100, error=18.000
# >epoch=293, lrate=0.100, error=20.000
# >epoch=294, lrate=0.100, error=31.000
# >epoch=295, lrate=0.100, error=22.000
# >epoch=296, lrate=0.100, error=16.000
# >epoch=297, lrate=0.100, error=24.000
# >epoch=298, lrate=0.100, error=22.000
# >epoch=299, lrate=0.100, error=24.000
# >epoch=300, lrate=0.100, error=27.000
# >epoch=301, lrate=0.100, error=17.000
# >epoch=302, lrate=0.100, error=17.000
# >epoch=303, lrate=0.100, error=21.000
# >epoch=304, lrate=0.100, error=16.000
# >epoch=305, lrate=0.100, error=24.000
# >epoch=306, lrate=0.100, error=18.000
# >epoch=307, lrate=0.100, error=26.000
# >epoch=308, lrate=0.100, error=17.000
# >epoch=309, lrate=0.100, error=26.000
# >epoch=310, lrate=0.100, error=15.000
# >epoch=311, lrate=0.100, error=26.000
# >epoch=312, lrate=0.100, error=18.000
# >epoch=313, lrate=0.100, error=21.000
# >epoch=314, lrate=0.100, error=21.000
# >epoch=315, lrate=0.100, error=23.000
# >epoch=316, lrate=0.100, error=20.000
# >epoch=317, lrate=0.100, error=20.000
# >epoch=318, lrate=0.100, error=21.000
# >epoch=319, lrate=0.100, error=20.000
# >epoch=320, lrate=0.100, error=22.000
# >epoch=321, lrate=0.100, error=28.000
# >epoch=322, lrate=0.100, error=18.000
# >epoch=323, lrate=0.100, error=15.000
# >epoch=324, lrate=0.100, error=24.000
# >epoch=325, lrate=0.100, error=17.000
# >epoch=326, lrate=0.100, error=26.000
# >epoch=327, lrate=0.100, error=15.000
# >epoch=328, lrate=0.100, error=22.000
# >epoch=329, lrate=0.100, error=23.000
# >epoch=330, lrate=0.100, error=23.000
# >epoch=331, lrate=0.100, error=20.000
# >epoch=332, lrate=0.100, error=11.000
# >epoch=333, lrate=0.100, error=24.000
# >epoch=334, lrate=0.100, error=22.000
# >epoch=335, lrate=0.100, error=14.000
# >epoch=336, lrate=0.100, error=19.000
# >epoch=337, lrate=0.100, error=19.000
# >epoch=338, lrate=0.100, error=16.000
# >epoch=339, lrate=0.100, error=20.000
# >epoch=340, lrate=0.100, error=27.000
# >epoch=341, lrate=0.100, error=18.000
# >epoch=342, lrate=0.100, error=22.000
# >epoch=343, lrate=0.100, error=20.000
# >epoch=344, lrate=0.100, error=15.000
# >epoch=345, lrate=0.100, error=27.000
# >epoch=346, lrate=0.100, error=29.000
# >epoch=347, lrate=0.100, error=16.000
# >epoch=348, lrate=0.100, error=22.000
# >epoch=349, lrate=0.100, error=17.000
# >epoch=350, lrate=0.100, error=19.000
# >epoch=351, lrate=0.100, error=27.000
# >epoch=352, lrate=0.100, error=18.000
# >epoch=353, lrate=0.100, error=18.000
# >epoch=354, lrate=0.100, error=19.000
# >epoch=355, lrate=0.100, error=17.000
# >epoch=356, lrate=0.100, error=30.000
# >epoch=357, lrate=0.100, error=19.000
# >epoch=358, lrate=0.100, error=28.000
# >epoch=359, lrate=0.100, error=13.000
# >epoch=360, lrate=0.100, error=27.000
# >epoch=361, lrate=0.100, error=17.000
# >epoch=362, lrate=0.100, error=24.000
# >epoch=363, lrate=0.100, error=25.000
# >epoch=364, lrate=0.100, error=16.000
# >epoch=365, lrate=0.100, error=25.000
# >epoch=366, lrate=0.100, error=27.000
# >epoch=367, lrate=0.100, error=17.000
# >epoch=368, lrate=0.100, error=12.000
# >epoch=369, lrate=0.100, error=17.000
# >epoch=370, lrate=0.100, error=14.000
# >epoch=371, lrate=0.100, error=22.000
# >epoch=372, lrate=0.100, error=22.000
# >epoch=373, lrate=0.100, error=22.000
# >epoch=374, lrate=0.100, error=19.000
# >epoch=375, lrate=0.100, error=25.000
# >epoch=376, lrate=0.100, error=20.000
# >epoch=377, lrate=0.100, error=14.000
# >epoch=378, lrate=0.100, error=18.000
# >epoch=379, lrate=0.100, error=16.000
# >epoch=380, lrate=0.100, error=21.000
# >epoch=381, lrate=0.100, error=18.000
# >epoch=382, lrate=0.100, error=20.000
# >epoch=383, lrate=0.100, error=16.000
# >epoch=384, lrate=0.100, error=20.000
# >epoch=385, lrate=0.100, error=15.000
# >epoch=386, lrate=0.100, error=16.000
# >epoch=387, lrate=0.100, error=34.000
# >epoch=388, lrate=0.100, error=20.000
# >epoch=389, lrate=0.100, error=22.000
# >epoch=390, lrate=0.100, error=28.000
# >epoch=391, lrate=0.100, error=12.000
# >epoch=392, lrate=0.100, error=19.000
# >epoch=393, lrate=0.100, error=19.000
# >epoch=394, lrate=0.100, error=23.000
# >epoch=395, lrate=0.100, error=26.000
# >epoch=396, lrate=0.100, error=14.000
# >epoch=397, lrate=0.100, error=24.000
# >epoch=398, lrate=0.100, error=18.000
# >epoch=399, lrate=0.100, error=25.000
# >epoch=400, lrate=0.100, error=18.000
# >epoch=401, lrate=0.100, error=23.000
# >epoch=402, lrate=0.100, error=15.000
# >epoch=403, lrate=0.100, error=19.000
# >epoch=404, lrate=0.100, error=22.000
# >epoch=405, lrate=0.100, error=20.000
# >epoch=406, lrate=0.100, error=16.000
# >epoch=407, lrate=0.100, error=20.000
# >epoch=408, lrate=0.100, error=15.000
# >epoch=409, lrate=0.100, error=27.000
# >epoch=410, lrate=0.100, error=16.000
# >epoch=411, lrate=0.100, error=26.000
# >epoch=412, lrate=0.100, error=21.000
# >epoch=413, lrate=0.100, error=19.000
# >epoch=414, lrate=0.100, error=19.000
# >epoch=415, lrate=0.100, error=25.000
# >epoch=416, lrate=0.100, error=17.000
# >epoch=417, lrate=0.100, error=16.000
# >epoch=418, lrate=0.100, error=24.000
# >epoch=419, lrate=0.100, error=19.000
# >epoch=420, lrate=0.100, error=29.000
# >epoch=421, lrate=0.100, error=23.000
# >epoch=422, lrate=0.100, error=20.000
# >epoch=423, lrate=0.100, error=22.000
# >epoch=424, lrate=0.100, error=22.000
# >epoch=425, lrate=0.100, error=20.000
# >epoch=426, lrate=0.100, error=19.000
# >epoch=427, lrate=0.100, error=15.000
# >epoch=428, lrate=0.100, error=18.000
# >epoch=429, lrate=0.100, error=13.000
# >epoch=430, lrate=0.100, error=21.000
# >epoch=431, lrate=0.100, error=17.000
# >epoch=432, lrate=0.100, error=23.000
# >epoch=433, lrate=0.100, error=22.000
# >epoch=434, lrate=0.100, error=12.000
# >epoch=435, lrate=0.100, error=17.000
# >epoch=436, lrate=0.100, error=22.000
# >epoch=437, lrate=0.100, error=25.000
# >epoch=438, lrate=0.100, error=14.000
# >epoch=439, lrate=0.100, error=29.000
# >epoch=440, lrate=0.100, error=22.000
# >epoch=441, lrate=0.100, error=22.000
# >epoch=442, lrate=0.100, error=24.000
# >epoch=443, lrate=0.100, error=14.000
# >epoch=444, lrate=0.100, error=17.000
# >epoch=445, lrate=0.100, error=19.000
# >epoch=446, lrate=0.100, error=19.000
# >epoch=447, lrate=0.100, error=17.000
# >epoch=448, lrate=0.100, error=17.000
# >epoch=449, lrate=0.100, error=21.000
# >epoch=450, lrate=0.100, error=24.000
# >epoch=451, lrate=0.100, error=18.000
# >epoch=452, lrate=0.100, error=30.000
# >epoch=453, lrate=0.100, error=19.000
# >epoch=454, lrate=0.100, error=17.000
# >epoch=455, lrate=0.100, error=17.000
# >epoch=456, lrate=0.100, error=22.000
# >epoch=457, lrate=0.100, error=17.000
# >epoch=458, lrate=0.100, error=21.000
# >epoch=459, lrate=0.100, error=15.000
# >epoch=460, lrate=0.100, error=16.000
# >epoch=461, lrate=0.100, error=20.000
# >epoch=462, lrate=0.100, error=20.000
# >epoch=463, lrate=0.100, error=20.000
# >epoch=464, lrate=0.100, error=18.000
# >epoch=465, lrate=0.100, error=30.000
# >epoch=466, lrate=0.100, error=23.000
# >epoch=467, lrate=0.100, error=28.000
# >epoch=468, lrate=0.100, error=17.000
# >epoch=469, lrate=0.100, error=24.000
# >epoch=470, lrate=0.100, error=14.000
# >epoch=471, lrate=0.100, error=17.000
# >epoch=472, lrate=0.100, error=17.000
# >epoch=473, lrate=0.100, error=17.000
# >epoch=474, lrate=0.100, error=16.000
# >epoch=475, lrate=0.100, error=16.000
# >epoch=476, lrate=0.100, error=18.000
# >epoch=477, lrate=0.100, error=25.000
# >epoch=478, lrate=0.100, error=18.000
# >epoch=479, lrate=0.100, error=14.000
# >epoch=480, lrate=0.100, error=16.000
# >epoch=481, lrate=0.100, error=15.000
# >epoch=482, lrate=0.100, error=24.000
# >epoch=483, lrate=0.100, error=19.000
# >epoch=484, lrate=0.100, error=18.000
# >epoch=485, lrate=0.100, error=22.000
# >epoch=486, lrate=0.100, error=20.000
# >epoch=487, lrate=0.100, error=17.000
# >epoch=488, lrate=0.100, error=17.000
# >epoch=489, lrate=0.100, error=15.000
# >epoch=490, lrate=0.100, error=23.000
# >epoch=491, lrate=0.100, error=18.000
# >epoch=492, lrate=0.100, error=26.000
# >epoch=493, lrate=0.100, error=15.000
# >epoch=494, lrate=0.100, error=20.000
# >epoch=495, lrate=0.100, error=26.000
# >epoch=496, lrate=0.100, error=27.000
# >epoch=497, lrate=0.100, error=14.000
# >epoch=498, lrate=0.100, error=21.000
# >epoch=499, lrate=0.100, error=20.000
# >epoch=0, lrate=0.100, error=65.000
# >epoch=1, lrate=0.100, error=57.000
# >epoch=2, lrate=0.100, error=48.000
# >epoch=3, lrate=0.100, error=51.000
# >epoch=4, lrate=0.100, error=55.000
# >epoch=5, lrate=0.100, error=45.000
# >epoch=6, lrate=0.100, error=34.000
# >epoch=7, lrate=0.100, error=45.000
# >epoch=8, lrate=0.100, error=57.000
# >epoch=9, lrate=0.100, error=40.000
# >epoch=10, lrate=0.100, error=44.000
# >epoch=11, lrate=0.100, error=47.000
# >epoch=12, lrate=0.100, error=35.000
# >epoch=13, lrate=0.100, error=39.000
# >epoch=14, lrate=0.100, error=42.000
# >epoch=15, lrate=0.100, error=43.000
# >epoch=16, lrate=0.100, error=48.000
# >epoch=17, lrate=0.100, error=33.000
# >epoch=18, lrate=0.100, error=41.000
# >epoch=19, lrate=0.100, error=33.000
# >epoch=20, lrate=0.100, error=41.000
# >epoch=21, lrate=0.100, error=36.000
# >epoch=22, lrate=0.100, error=33.000
# >epoch=23, lrate=0.100, error=35.000
# >epoch=24, lrate=0.100, error=28.000
# >epoch=25, lrate=0.100, error=30.000
# >epoch=26, lrate=0.100, error=33.000
# >epoch=27, lrate=0.100, error=30.000
# >epoch=28, lrate=0.100, error=27.000
# >epoch=29, lrate=0.100, error=29.000
# >epoch=30, lrate=0.100, error=34.000
# >epoch=31, lrate=0.100, error=34.000
# >epoch=32, lrate=0.100, error=32.000
# >epoch=33, lrate=0.100, error=25.000
# >epoch=34, lrate=0.100, error=32.000
# >epoch=35, lrate=0.100, error=32.000
# >epoch=36, lrate=0.100, error=25.000
# >epoch=37, lrate=0.100, error=25.000
# >epoch=38, lrate=0.100, error=25.000
# >epoch=39, lrate=0.100, error=38.000
# >epoch=40, lrate=0.100, error=28.000
# >epoch=41, lrate=0.100, error=24.000
# >epoch=42, lrate=0.100, error=22.000
# >epoch=43, lrate=0.100, error=24.000
# >epoch=44, lrate=0.100, error=37.000
# >epoch=45, lrate=0.100, error=24.000
# >epoch=46, lrate=0.100, error=35.000
# >epoch=47, lrate=0.100, error=31.000
# >epoch=48, lrate=0.100, error=28.000
# >epoch=49, lrate=0.100, error=33.000
# >epoch=50, lrate=0.100, error=25.000
# >epoch=51, lrate=0.100, error=31.000
# >epoch=52, lrate=0.100, error=35.000
# >epoch=53, lrate=0.100, error=25.000
# >epoch=54, lrate=0.100, error=30.000
# >epoch=55, lrate=0.100, error=24.000
# >epoch=56, lrate=0.100, error=23.000
# >epoch=57, lrate=0.100, error=28.000
# >epoch=58, lrate=0.100, error=26.000
# >epoch=59, lrate=0.100, error=38.000
# >epoch=60, lrate=0.100, error=25.000
# >epoch=61, lrate=0.100, error=27.000
# >epoch=62, lrate=0.100, error=25.000
# >epoch=63, lrate=0.100, error=24.000
# >epoch=64, lrate=0.100, error=31.000
# >epoch=65, lrate=0.100, error=27.000
# >epoch=66, lrate=0.100, error=26.000
# >epoch=67, lrate=0.100, error=22.000
# >epoch=68, lrate=0.100, error=22.000
# >epoch=69, lrate=0.100, error=26.000
# >epoch=70, lrate=0.100, error=30.000
# >epoch=71, lrate=0.100, error=19.000
# >epoch=72, lrate=0.100, error=21.000
# >epoch=73, lrate=0.100, error=20.000
# >epoch=74, lrate=0.100, error=24.000
# >epoch=75, lrate=0.100, error=20.000
# >epoch=76, lrate=0.100, error=27.000
# >epoch=77, lrate=0.100, error=27.000
# >epoch=78, lrate=0.100, error=24.000
# >epoch=79, lrate=0.100, error=16.000
# >epoch=80, lrate=0.100, error=23.000
# >epoch=81, lrate=0.100, error=20.000
# >epoch=82, lrate=0.100, error=25.000
# >epoch=83, lrate=0.100, error=23.000
# >epoch=84, lrate=0.100, error=29.000
# >epoch=85, lrate=0.100, error=35.000
# >epoch=86, lrate=0.100, error=33.000
# >epoch=87, lrate=0.100, error=29.000
# >epoch=88, lrate=0.100, error=23.000
# >epoch=89, lrate=0.100, error=23.000
# >epoch=90, lrate=0.100, error=24.000
# >epoch=91, lrate=0.100, error=24.000
# >epoch=92, lrate=0.100, error=19.000
# >epoch=93, lrate=0.100, error=20.000
# >epoch=94, lrate=0.100, error=21.000
# >epoch=95, lrate=0.100, error=22.000
# >epoch=96, lrate=0.100, error=28.000
# >epoch=97, lrate=0.100, error=25.000
# >epoch=98, lrate=0.100, error=31.000
# >epoch=99, lrate=0.100, error=35.000
# >epoch=100, lrate=0.100, error=32.000
# >epoch=101, lrate=0.100, error=29.000
# >epoch=102, lrate=0.100, error=22.000
# >epoch=103, lrate=0.100, error=20.000
# >epoch=104, lrate=0.100, error=32.000
# >epoch=105, lrate=0.100, error=27.000
# >epoch=106, lrate=0.100, error=27.000
# >epoch=107, lrate=0.100, error=18.000
# >epoch=108, lrate=0.100, error=17.000
# >epoch=109, lrate=0.100, error=26.000
# >epoch=110, lrate=0.100, error=22.000
# >epoch=111, lrate=0.100, error=27.000
# >epoch=112, lrate=0.100, error=27.000
# >epoch=113, lrate=0.100, error=30.000
# >epoch=114, lrate=0.100, error=28.000
# >epoch=115, lrate=0.100, error=23.000
# >epoch=116, lrate=0.100, error=27.000
# >epoch=117, lrate=0.100, error=21.000
# >epoch=118, lrate=0.100, error=32.000
# >epoch=119, lrate=0.100, error=26.000
# >epoch=120, lrate=0.100, error=16.000
# >epoch=121, lrate=0.100, error=21.000
# >epoch=122, lrate=0.100, error=27.000
# >epoch=123, lrate=0.100, error=21.000
# >epoch=124, lrate=0.100, error=22.000
# >epoch=125, lrate=0.100, error=21.000
# >epoch=126, lrate=0.100, error=19.000
# >epoch=127, lrate=0.100, error=36.000
# >epoch=128, lrate=0.100, error=17.000
# >epoch=129, lrate=0.100, error=22.000
# >epoch=130, lrate=0.100, error=18.000
# >epoch=131, lrate=0.100, error=28.000
# >epoch=132, lrate=0.100, error=17.000
# >epoch=133, lrate=0.100, error=29.000
# >epoch=134, lrate=0.100, error=23.000
# >epoch=135, lrate=0.100, error=17.000
# >epoch=136, lrate=0.100, error=36.000
# >epoch=137, lrate=0.100, error=16.000
# >epoch=138, lrate=0.100, error=17.000
# >epoch=139, lrate=0.100, error=17.000
# >epoch=140, lrate=0.100, error=19.000
# >epoch=141, lrate=0.100, error=17.000
# >epoch=142, lrate=0.100, error=17.000
# >epoch=143, lrate=0.100, error=19.000
# >epoch=144, lrate=0.100, error=22.000
# >epoch=145, lrate=0.100, error=23.000
# >epoch=146, lrate=0.100, error=26.000
# >epoch=147, lrate=0.100, error=22.000
# >epoch=148, lrate=0.100, error=17.000
# >epoch=149, lrate=0.100, error=14.000
# >epoch=150, lrate=0.100, error=25.000
# >epoch=151, lrate=0.100, error=22.000
# >epoch=152, lrate=0.100, error=24.000
# >epoch=153, lrate=0.100, error=22.000
# >epoch=154, lrate=0.100, error=24.000
# >epoch=155, lrate=0.100, error=27.000
# >epoch=156, lrate=0.100, error=23.000
# >epoch=157, lrate=0.100, error=25.000
# >epoch=158, lrate=0.100, error=26.000
# >epoch=159, lrate=0.100, error=18.000
# >epoch=160, lrate=0.100, error=26.000
# >epoch=161, lrate=0.100, error=14.000
# >epoch=162, lrate=0.100, error=16.000
# >epoch=163, lrate=0.100, error=20.000
# >epoch=164, lrate=0.100, error=26.000
# >epoch=165, lrate=0.100, error=22.000
# >epoch=166, lrate=0.100, error=20.000
# >epoch=167, lrate=0.100, error=19.000
# >epoch=168, lrate=0.100, error=21.000
# >epoch=169, lrate=0.100, error=17.000
# >epoch=170, lrate=0.100, error=16.000
# >epoch=171, lrate=0.100, error=20.000
# >epoch=172, lrate=0.100, error=26.000
# >epoch=173, lrate=0.100, error=20.000
# >epoch=174, lrate=0.100, error=24.000
# >epoch=175, lrate=0.100, error=24.000
# >epoch=176, lrate=0.100, error=29.000
# >epoch=177, lrate=0.100, error=22.000
# >epoch=178, lrate=0.100, error=31.000
# >epoch=179, lrate=0.100, error=21.000
# >epoch=180, lrate=0.100, error=22.000
# >epoch=181, lrate=0.100, error=25.000
# >epoch=182, lrate=0.100, error=15.000
# >epoch=183, lrate=0.100, error=25.000
# >epoch=184, lrate=0.100, error=19.000
# >epoch=185, lrate=0.100, error=20.000
# >epoch=186, lrate=0.100, error=29.000
# >epoch=187, lrate=0.100, error=17.000
# >epoch=188, lrate=0.100, error=12.000
# >epoch=189, lrate=0.100, error=33.000
# >epoch=190, lrate=0.100, error=24.000
# >epoch=191, lrate=0.100, error=24.000
# >epoch=192, lrate=0.100, error=22.000
# >epoch=193, lrate=0.100, error=15.000
# >epoch=194, lrate=0.100, error=15.000
# >epoch=195, lrate=0.100, error=15.000
# >epoch=196, lrate=0.100, error=16.000
# >epoch=197, lrate=0.100, error=29.000
# >epoch=198, lrate=0.100, error=21.000
# >epoch=199, lrate=0.100, error=22.000
# >epoch=200, lrate=0.100, error=29.000
# >epoch=201, lrate=0.100, error=15.000
# >epoch=202, lrate=0.100, error=23.000
# >epoch=203, lrate=0.100, error=20.000
# >epoch=204, lrate=0.100, error=23.000
# >epoch=205, lrate=0.100, error=26.000
# >epoch=206, lrate=0.100, error=24.000
# >epoch=207, lrate=0.100, error=19.000
# >epoch=208, lrate=0.100, error=25.000
# >epoch=209, lrate=0.100, error=21.000
# >epoch=210, lrate=0.100, error=15.000
# >epoch=211, lrate=0.100, error=25.000
# >epoch=212, lrate=0.100, error=22.000
# >epoch=213, lrate=0.100, error=23.000
# >epoch=214, lrate=0.100, error=16.000
# >epoch=215, lrate=0.100, error=14.000
# >epoch=216, lrate=0.100, error=15.000
# >epoch=217, lrate=0.100, error=15.000
# >epoch=218, lrate=0.100, error=21.000
# >epoch=219, lrate=0.100, error=27.000
# >epoch=220, lrate=0.100, error=24.000
# >epoch=221, lrate=0.100, error=16.000
# >epoch=222, lrate=0.100, error=17.000
# >epoch=223, lrate=0.100, error=17.000
# >epoch=224, lrate=0.100, error=24.000
# >epoch=225, lrate=0.100, error=27.000
# >epoch=226, lrate=0.100, error=11.000
# >epoch=227, lrate=0.100, error=16.000
# >epoch=228, lrate=0.100, error=16.000
# >epoch=229, lrate=0.100, error=29.000
# >epoch=230, lrate=0.100, error=23.000
# >epoch=231, lrate=0.100, error=13.000
# >epoch=232, lrate=0.100, error=25.000
# >epoch=233, lrate=0.100, error=19.000
# >epoch=234, lrate=0.100, error=20.000
# >epoch=235, lrate=0.100, error=23.000
# >epoch=236, lrate=0.100, error=25.000
# >epoch=237, lrate=0.100, error=12.000
# >epoch=238, lrate=0.100, error=19.000
# >epoch=239, lrate=0.100, error=12.000
# >epoch=240, lrate=0.100, error=19.000
# >epoch=241, lrate=0.100, error=18.000
# >epoch=242, lrate=0.100, error=16.000
# >epoch=243, lrate=0.100, error=18.000
# >epoch=244, lrate=0.100, error=15.000
# >epoch=245, lrate=0.100, error=20.000
# >epoch=246, lrate=0.100, error=17.000
# >epoch=247, lrate=0.100, error=16.000
# >epoch=248, lrate=0.100, error=20.000
# >epoch=249, lrate=0.100, error=21.000
# >epoch=250, lrate=0.100, error=15.000
# >epoch=251, lrate=0.100, error=17.000
# >epoch=252, lrate=0.100, error=27.000
# >epoch=253, lrate=0.100, error=21.000
# >epoch=254, lrate=0.100, error=14.000
# >epoch=255, lrate=0.100, error=29.000
# >epoch=256, lrate=0.100, error=20.000
# >epoch=257, lrate=0.100, error=17.000
# >epoch=258, lrate=0.100, error=18.000
# >epoch=259, lrate=0.100, error=16.000
# >epoch=260, lrate=0.100, error=14.000
# >epoch=261, lrate=0.100, error=15.000
# >epoch=262, lrate=0.100, error=13.000
# >epoch=263, lrate=0.100, error=14.000
# >epoch=264, lrate=0.100, error=21.000
# >epoch=265, lrate=0.100, error=14.000
# >epoch=266, lrate=0.100, error=11.000
# >epoch=267, lrate=0.100, error=20.000
# >epoch=268, lrate=0.100, error=22.000
# >epoch=269, lrate=0.100, error=31.000
# >epoch=270, lrate=0.100, error=20.000
# >epoch=271, lrate=0.100, error=14.000
# >epoch=272, lrate=0.100, error=17.000
# >epoch=273, lrate=0.100, error=21.000
# >epoch=274, lrate=0.100, error=20.000
# >epoch=275, lrate=0.100, error=16.000
# >epoch=276, lrate=0.100, error=19.000
# >epoch=277, lrate=0.100, error=23.000
# >epoch=278, lrate=0.100, error=15.000
# >epoch=279, lrate=0.100, error=21.000
# >epoch=280, lrate=0.100, error=20.000
# >epoch=281, lrate=0.100, error=22.000
# >epoch=282, lrate=0.100, error=15.000
# >epoch=283, lrate=0.100, error=25.000
# >epoch=284, lrate=0.100, error=18.000
# >epoch=285, lrate=0.100, error=21.000
# >epoch=286, lrate=0.100, error=27.000
# >epoch=287, lrate=0.100, error=20.000
# >epoch=288, lrate=0.100, error=21.000
# >epoch=289, lrate=0.100, error=15.000
# >epoch=290, lrate=0.100, error=25.000
# >epoch=291, lrate=0.100, error=15.000
# >epoch=292, lrate=0.100, error=15.000
# >epoch=293, lrate=0.100, error=15.000
# >epoch=294, lrate=0.100, error=20.000
# >epoch=295, lrate=0.100, error=23.000
# >epoch=296, lrate=0.100, error=22.000
# >epoch=297, lrate=0.100, error=18.000
# >epoch=298, lrate=0.100, error=14.000
# >epoch=299, lrate=0.100, error=13.000
# >epoch=300, lrate=0.100, error=29.000
# >epoch=301, lrate=0.100, error=10.000
# >epoch=302, lrate=0.100, error=19.000
# >epoch=303, lrate=0.100, error=15.000
# >epoch=304, lrate=0.100, error=14.000
# >epoch=305, lrate=0.100, error=15.000
# >epoch=306, lrate=0.100, error=15.000
# >epoch=307, lrate=0.100, error=20.000
# >epoch=308, lrate=0.100, error=29.000
# >epoch=309, lrate=0.100, error=29.000
# >epoch=310, lrate=0.100, error=20.000
# >epoch=311, lrate=0.100, error=20.000
# >epoch=312, lrate=0.100, error=20.000
# >epoch=313, lrate=0.100, error=14.000
# >epoch=314, lrate=0.100, error=20.000
# >epoch=315, lrate=0.100, error=12.000
# >epoch=316, lrate=0.100, error=32.000
# >epoch=317, lrate=0.100, error=20.000
# >epoch=318, lrate=0.100, error=21.000
# >epoch=319, lrate=0.100, error=15.000
# >epoch=320, lrate=0.100, error=10.000
# >epoch=321, lrate=0.100, error=13.000
# >epoch=322, lrate=0.100, error=12.000
# >epoch=323, lrate=0.100, error=18.000
# >epoch=324, lrate=0.100, error=19.000
# >epoch=325, lrate=0.100, error=13.000
# >epoch=326, lrate=0.100, error=28.000
# >epoch=327, lrate=0.100, error=17.000
# >epoch=328, lrate=0.100, error=16.000
# >epoch=329, lrate=0.100, error=16.000
# >epoch=330, lrate=0.100, error=11.000
# >epoch=331, lrate=0.100, error=17.000
# >epoch=332, lrate=0.100, error=19.000
# >epoch=333, lrate=0.100, error=23.000
# >epoch=334, lrate=0.100, error=16.000
# >epoch=335, lrate=0.100, error=22.000
# >epoch=336, lrate=0.100, error=19.000
# >epoch=337, lrate=0.100, error=15.000
# >epoch=338, lrate=0.100, error=19.000
# >epoch=339, lrate=0.100, error=16.000
# >epoch=340, lrate=0.100, error=18.000
# >epoch=341, lrate=0.100, error=25.000
# >epoch=342, lrate=0.100, error=15.000
# >epoch=343, lrate=0.100, error=15.000
# >epoch=344, lrate=0.100, error=13.000
# >epoch=345, lrate=0.100, error=19.000
# >epoch=346, lrate=0.100, error=30.000
# >epoch=347, lrate=0.100, error=13.000
# >epoch=348, lrate=0.100, error=16.000
# >epoch=349, lrate=0.100, error=14.000
# >epoch=350, lrate=0.100, error=25.000
# >epoch=351, lrate=0.100, error=16.000
# >epoch=352, lrate=0.100, error=14.000
# >epoch=353, lrate=0.100, error=17.000
# >epoch=354, lrate=0.100, error=13.000
# >epoch=355, lrate=0.100, error=16.000
# >epoch=356, lrate=0.100, error=17.000
# >epoch=357, lrate=0.100, error=25.000
# >epoch=358, lrate=0.100, error=21.000
# >epoch=359, lrate=0.100, error=14.000
# >epoch=360, lrate=0.100, error=19.000
# >epoch=361, lrate=0.100, error=21.000
# >epoch=362, lrate=0.100, error=14.000
# >epoch=363, lrate=0.100, error=16.000
# >epoch=364, lrate=0.100, error=16.000
# >epoch=365, lrate=0.100, error=28.000
# >epoch=366, lrate=0.100, error=16.000
# >epoch=367, lrate=0.100, error=15.000
# >epoch=368, lrate=0.100, error=22.000
# >epoch=369, lrate=0.100, error=17.000
# >epoch=370, lrate=0.100, error=11.000
# >epoch=371, lrate=0.100, error=13.000
# >epoch=372, lrate=0.100, error=31.000
# >epoch=373, lrate=0.100, error=17.000
# >epoch=374, lrate=0.100, error=15.000
# >epoch=375, lrate=0.100, error=23.000
# >epoch=376, lrate=0.100, error=15.000
# >epoch=377, lrate=0.100, error=17.000
# >epoch=378, lrate=0.100, error=19.000
# >epoch=379, lrate=0.100, error=22.000
# >epoch=380, lrate=0.100, error=14.000
# >epoch=381, lrate=0.100, error=14.000
# >epoch=382, lrate=0.100, error=18.000
# >epoch=383, lrate=0.100, error=14.000
# >epoch=384, lrate=0.100, error=12.000
# >epoch=385, lrate=0.100, error=17.000
# >epoch=386, lrate=0.100, error=21.000
# >epoch=387, lrate=0.100, error=16.000
# >epoch=388, lrate=0.100, error=13.000
# >epoch=389, lrate=0.100, error=25.000
# >epoch=390, lrate=0.100, error=17.000
# >epoch=391, lrate=0.100, error=18.000
# >epoch=392, lrate=0.100, error=26.000
# >epoch=393, lrate=0.100, error=16.000
# >epoch=394, lrate=0.100, error=16.000
# >epoch=395, lrate=0.100, error=24.000
# >epoch=396, lrate=0.100, error=12.000
# >epoch=397, lrate=0.100, error=14.000
# >epoch=398, lrate=0.100, error=14.000
# >epoch=399, lrate=0.100, error=14.000
# >epoch=400, lrate=0.100, error=14.000
# >epoch=401, lrate=0.100, error=13.000
# >epoch=402, lrate=0.100, error=25.000
# >epoch=403, lrate=0.100, error=13.000
# >epoch=404, lrate=0.100, error=16.000
# >epoch=405, lrate=0.100, error=16.000
# >epoch=406, lrate=0.100, error=14.000
# >epoch=407, lrate=0.100, error=16.000
# >epoch=408, lrate=0.100, error=14.000
# >epoch=409, lrate=0.100, error=20.000
# >epoch=410, lrate=0.100, error=15.000
# >epoch=411, lrate=0.100, error=13.000
# >epoch=412, lrate=0.100, error=15.000
# >epoch=413, lrate=0.100, error=14.000
# >epoch=414, lrate=0.100, error=11.000
# >epoch=415, lrate=0.100, error=20.000
# >epoch=416, lrate=0.100, error=28.000
# >epoch=417, lrate=0.100, error=14.000
# >epoch=418, lrate=0.100, error=18.000
# >epoch=419, lrate=0.100, error=16.000
# >epoch=420, lrate=0.100, error=14.000
# >epoch=421, lrate=0.100, error=33.000
# >epoch=422, lrate=0.100, error=15.000
# >epoch=423, lrate=0.100, error=16.000
# >epoch=424, lrate=0.100, error=14.000
# >epoch=425, lrate=0.100, error=16.000
# >epoch=426, lrate=0.100, error=16.000
# >epoch=427, lrate=0.100, error=14.000
# >epoch=428, lrate=0.100, error=12.000
# >epoch=429, lrate=0.100, error=21.000
# >epoch=430, lrate=0.100, error=19.000
# >epoch=431, lrate=0.100, error=22.000
# >epoch=432, lrate=0.100, error=22.000
# >epoch=433, lrate=0.100, error=10.000
# >epoch=434, lrate=0.100, error=14.000
# >epoch=435, lrate=0.100, error=13.000
# >epoch=436, lrate=0.100, error=13.000
# >epoch=437, lrate=0.100, error=12.000
# >epoch=438, lrate=0.100, error=25.000
# >epoch=439, lrate=0.100, error=28.000
# >epoch=440, lrate=0.100, error=11.000
# >epoch=441, lrate=0.100, error=14.000
# >epoch=442, lrate=0.100, error=15.000
# >epoch=443, lrate=0.100, error=22.000
# >epoch=444, lrate=0.100, error=24.000
# >epoch=445, lrate=0.100, error=14.000
# >epoch=446, lrate=0.100, error=18.000
# >epoch=447, lrate=0.100, error=18.000
# >epoch=448, lrate=0.100, error=14.000
# >epoch=449, lrate=0.100, error=16.000
# >epoch=450, lrate=0.100, error=15.000
# >epoch=451, lrate=0.100, error=17.000
# >epoch=452, lrate=0.100, error=12.000
# >epoch=453, lrate=0.100, error=15.000
# >epoch=454, lrate=0.100, error=18.000
# >epoch=455, lrate=0.100, error=18.000
# >epoch=456, lrate=0.100, error=16.000
# >epoch=457, lrate=0.100, error=18.000
# >epoch=458, lrate=0.100, error=16.000
# >epoch=459, lrate=0.100, error=18.000
# >epoch=460, lrate=0.100, error=23.000
# >epoch=461, lrate=0.100, error=8.000
# >epoch=462, lrate=0.100, error=8.000
# >epoch=463, lrate=0.100, error=13.000
# >epoch=464, lrate=0.100, error=14.000
# >epoch=465, lrate=0.100, error=16.000
# >epoch=466, lrate=0.100, error=13.000
# >epoch=467, lrate=0.100, error=27.000
# >epoch=468, lrate=0.100, error=21.000
# >epoch=469, lrate=0.100, error=12.000
# >epoch=470, lrate=0.100, error=19.000
# >epoch=471, lrate=0.100, error=8.000
# >epoch=472, lrate=0.100, error=13.000
# >epoch=473, lrate=0.100, error=17.000
# >epoch=474, lrate=0.100, error=17.000
# >epoch=475, lrate=0.100, error=15.000
# >epoch=476, lrate=0.100, error=14.000
# >epoch=477, lrate=0.100, error=7.000
# >epoch=478, lrate=0.100, error=13.000
# >epoch=479, lrate=0.100, error=12.000
# >epoch=480, lrate=0.100, error=8.000
# >epoch=481, lrate=0.100, error=13.000
# >epoch=482, lrate=0.100, error=18.000
# >epoch=483, lrate=0.100, error=14.000
# >epoch=484, lrate=0.100, error=21.000
# >epoch=485, lrate=0.100, error=13.000
# >epoch=486, lrate=0.100, error=16.000
# >epoch=487, lrate=0.100, error=16.000
# >epoch=488, lrate=0.100, error=18.000
# >epoch=489, lrate=0.100, error=14.000
# >epoch=490, lrate=0.100, error=10.000
# >epoch=491, lrate=0.100, error=9.000
# >epoch=492, lrate=0.100, error=9.000
# >epoch=493, lrate=0.100, error=15.000
# >epoch=494, lrate=0.100, error=15.000
# >epoch=495, lrate=0.100, error=22.000
# >epoch=496, lrate=0.100, error=11.000
# >epoch=497, lrate=0.100, error=17.000
# >epoch=498, lrate=0.100, error=17.000
# >epoch=499, lrate=0.100, error=16.000
# Scores: [78.26086956521739, 75.36231884057972, 68.11594202898551]
# Mean Accuracy: 73.913%
